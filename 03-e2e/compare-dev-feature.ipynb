# %% [markdown]
# # Comparing dev and feature
#
# This notebook compares results between dev and feature titiler deployments. Running end-to-end benchmarks is documented in [https://github.com/developmentseed/tile-benchmarking/tree/main/03-e2e/README.md](https://github.com/developmentseed/tile-benchmarking/tree/main/03-e2e/README.md).
#
# This notebook is comparing titiler-xarray's dev branch at [commit 9ac1686612d](https://github.com/developmentseed/titiler-xarray/commit/9ac1686612d706e0f078a418818b16544efb11c0) with a feature deployment that includes [diskcache](https://github.com/developmentseed/titiler-xarray/commit/283bc839e081d8cfe8bc730cf3fc0f2d344e3ec4)

# %%
# Import libraries
import os
import pandas as pd
import hvplot.pandas
import holoviews as hv
pd.options.plotting.backend = 'holoviews'
import warnings
warnings.filterwarnings('ignore')
import sys
sys.path.append('..')
from helpers import dataframe
# You will need to set credentials to access nasa-eodc-data-store
# import eodc_hub_role
# credentials = eodc_hub_role.fetch_and_set_credentials()
# Out:
# /Users/aimeebarciauskas/miniconda3/lib/python3.9/site-packages/pandas/core/computation/expressions.py:21: UserWarning: Pandas requires version '2.8.0' or newer of 'numexpr' (version '2.7.3' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>

# %%
# Remove any previous results
# !rm -rf downloaded_dev_results/
# !rm -rf downloaded_feature_results/

# %%
# %%capture
# !aws s3 cp --recursive s3://nasa-eodc-data-store/tile-benchmarking-results/2023-10-20_18-22-23/ downloaded_dev_results/
# !aws s3 cp --recursive s3://nasa-eodc-data-store/tile-benchmarking-results/2023-10-20_18-13-40/ downloaded_feature_results/

# %% [markdown]
# Parse and merge results into a single dataframe.

# %%
results = { 'feature': {}, 'dev': {} }
for env in results.keys():
    # Specify the directory path and the suffix
    directory_path = f"downloaded_{env}_results/"
    suffix = "_urls_stats.csv"  # For example, if you're interested in text files

    # List all files in the directory
    all_files = os.listdir(directory_path)

    # Filter the files to only include those that end with the specified suffix
    files_with_suffix = [f"{directory_path}{f}" for f in all_files if f.endswith(suffix)]

    dfs = []
    for file in files_with_suffix:
        df = pd.read_csv(file)
        df['file'] = file
        dfs.append(df)

    merged_df = pd.concat(dfs)
    merged_df['dataset'] = [file.split('/')[1].replace('_urls_stats.csv', '') for file in merged_df['file']]
    results[env]['all'] = merged_df
    # The "Aggregated" results represent aggregations across tile endpoints. 
    results[env][f'Aggregated {env}'] = merged_df[merged_df['Name'] == 'Aggregated']

# %%
dataset_specs_all = dataframe.csv_to_pandas('zarr_info.csv')
#dataset_specs_all

# %%
dev_df = results['dev'][f'Aggregated dev']
feature_df = results['feature'][f'Aggregated feature']
merged_df = pd.merge(dev_df, feature_df,  on='dataset', suffixes=(' Dev', ' Feature'))
merged_df['Failure Rate Dev'] = merged_df['Failure Count Dev']/merged_df['Request Count Dev'] * 100
merged_df['Failure Rate Feature'] = merged_df['Failure Count Feature']/merged_df['Request Count Feature'] * 100

summary_df = merged_df[['Average Response Time Dev', 'Failure Rate Dev', 'Average Response Time Feature', 'Failure Rate Feature', 'dataset']].sort_values('Average Response Time Dev')
merged_specs = summary_df.merge(dataset_specs_all, left_on='dataset', right_on='collection_name')

# %%
merged_specs
# Out:
#     Average Response Time Dev  Failure Rate Dev  \
# 0                  289.621658               0.0
# 1                  319.338632               0.0
# 2                  332.697947               0.0
# 3                  334.265461               0.0
# 4                  404.687215               0.0
# 5                  492.205420               0.0
# 6                  519.183636               0.0
# 7                  519.816283               0.0
# 8                  558.456119               0.0
# 9                  567.081987               0.0
# 10                 569.098768               0.0
# 11                 580.670218               0.0
# 12                 597.989524               0.0
# 13                 600.312950               0.0
# 14                 607.673037               0.0
# 15                 664.358879               0.0
# 16                 866.703419               0.0
# 17                 932.461655               0.0
# 18                1608.629377               0.0
# 19                3100.361618               0.0
# 20                7515.311437               0.0
#
#     Average Response Time Feature  Failure Rate Feature  \
# 0                      231.326141                   0.0
# 1                      207.038560                   0.0
# 2                      244.945579                   0.0
# 3                      275.572622                   0.0
# 4                      331.215422                   0.0
# 5                      418.354628                   0.0
# 6                      307.487830                   0.0
# 7                      218.855533                   0.0
# 8                      359.963568                   0.0
# 9                      492.673099                   0.0
# 10                     503.212403                   0.0
# 11                     430.382263                   0.0
# 12                     500.982266                   0.0
# 13                     536.298851                   0.0
# 14                     550.481232                   0.0
# 15                     594.515245                   0.0
# 16                     757.555906                   0.0
# 17                     853.120543                   0.0
# 18                    1543.147565                   0.0
# 19                    3095.555633                   0.0
# 20                     887.781695                   0.0
#
#                                               dataset  \
# 0              single_chunk_store_lat512_lon1024.zarr
# 1         600_1440_1_CMIP6_daily_GISS-E2-1-G_tas.zarr
# 2                                      cmip6-kerchunk
# 3              single_chunk_store_lat724_lon1448.zarr
# 4             single_chunk_store_lat1024_lon2048.zarr
# 5              with_chunks_store_lat2048_lon4096.zarr
# 6              power_901_monthly_meteorology_utc.zarr
# 7    pr_day_ACCESS-CM2_historical_r1i1p1f1_gn_1950.nc
# 8                  aws-noaa-oisst-feedstock_reference
# 9              with_chunks_store_lat1448_lon2896.zarr
# 10            single_chunk_store_lat1448_lon2896.zarr
# 11               cmip6-pds_GISS-E2-1-G_historical_tas
# 12       600_1440_29_CMIP6_daily_GISS-E2-1-G_tas.zarr
# 13             with_chunks_store_lat2896_lon5792.zarr
# 14             with_chunks_store_lat4096_lon8192.zarr
# 15            with_chunks_store_lat5793_lon11586.zarr
# 16       365_262_262_CMIP6_daily_GISS-E2-1-G_tas.zarr
# 17            single_chunk_store_lat2048_lon4096.zarr
# 18            single_chunk_store_lat2896_lon5792.zarr
# 19            single_chunk_store_lat4096_lon8192.zarr
# 20  prod-giovanni-cache-GPM_3IMERGHH_06_precipitat...
#
#                                       collection_name  \
# 0              single_chunk_store_lat512_lon1024.zarr
# 1         600_1440_1_CMIP6_daily_GISS-E2-1-G_tas.zarr
# 2                                      cmip6-kerchunk
# 3              single_chunk_store_lat724_lon1448.zarr
# 4             single_chunk_store_lat1024_lon2048.zarr
# 5              with_chunks_store_lat2048_lon4096.zarr
# 6              power_901_monthly_meteorology_utc.zarr
# 7    pr_day_ACCESS-CM2_historical_r1i1p1f1_gn_1950.nc
# 8                  aws-noaa-oisst-feedstock_reference
# 9              with_chunks_store_lat1448_lon2896.zarr
# 10            single_chunk_store_lat1448_lon2896.zarr
# 11               cmip6-pds_GISS-E2-1-G_historical_tas
# 12       600_1440_29_CMIP6_daily_GISS-E2-1-G_tas.zarr
# 13             with_chunks_store_lat2896_lon5792.zarr
# 14             with_chunks_store_lat4096_lon8192.zarr
# 15            with_chunks_store_lat5793_lon11586.zarr
# 16       365_262_262_CMIP6_daily_GISS-E2-1-G_tas.zarr
# 17            single_chunk_store_lat2048_lon4096.zarr
# 18            single_chunk_store_lat2896_lon5792.zarr
# 19            single_chunk_store_lat4096_lon8192.zarr
# 20  prod-giovanni-cache-GPM_3IMERGHH_06_precipitat...
#
#                                                source  \
# 0   s3://nasa-eodc-data-store/test-data/fake-data/...
# 1   s3://nasa-eodc-data-store/test-data/cmip6-zarr...
# 2   s3://nasa-eodc-data-store/test-data/cmip6-kerc...
# 3   s3://nasa-eodc-data-store/test-data/fake-data/...
# 4   s3://nasa-eodc-data-store/test-data/fake-data/...
# 5   s3://nasa-eodc-data-store/test-data/fake-data/...
# 6   s3://power-analysis-ready-datastore/power_901_...
# 7   https://nex-gddp-cmip6.s3-us-west-2.amazonaws....
# 8   https://ncsa.osn.xsede.org/Pangeo/pangeo-forge...
# 9   s3://nasa-eodc-data-store/test-data/fake-data/...
# 10  s3://nasa-eodc-data-store/test-data/fake-data/...
# 11  s3://cmip6-pds/CMIP6/CMIP/NASA-GISS/GISS-E2-1-...
# 12  s3://nasa-eodc-data-store/test-data/cmip6-zarr...
# 13  s3://nasa-eodc-data-store/test-data/fake-data/...
# 14  s3://nasa-eodc-data-store/test-data/fake-data/...
# 15  s3://nasa-eodc-data-store/test-data/fake-data/...
# 16  s3://nasa-eodc-data-store/test-data/cmip6-zarr...
# 17  s3://nasa-eodc-data-store/test-data/fake-data/...
# 18  s3://nasa-eodc-data-store/test-data/fake-data/...
# 19  s3://nasa-eodc-data-store/test-data/fake-data/...
# 20  s3://prod-giovanni-cache/zarr/GPM_3IMERGHH_06_...
#
#                            chunks                        shape_dict    dtype  \
# 0              {'y': 1, 'x': 512}             {'y': 512, 'x': 1024}  float64
# 1              {'y': 1, 'x': 600}             {'y': 600, 'x': 1440}  float32
# 2              {'y': 1, 'x': 600}             {'y': 600, 'x': 1440}  float32
# 3              {'y': 1, 'x': 724}             {'y': 724, 'x': 1448}  float64
# 4             {'y': 1, 'x': 1024}            {'y': 1024, 'x': 2048}  float64
# 5             {'y': 1, 'x': 1448}            {'y': 2048, 'x': 4096}  float64
# 6             {'y': 504, 'x': 25}              {'y': 361, 'x': 576}  float64
# 7            {'y': 'N', 'x': '/'}             {'y': 600, 'x': 1440}  float32
# 8   {'zlev': 1, 'y': 1, 'x': 720}  {'zlev': 1, 'y': 720, 'x': 1440}    int16
# 9             {'y': 1, 'x': 1448}            {'y': 1448, 'x': 2896}  float64
# 10            {'y': 1, 'x': 1448}            {'y': 1448, 'x': 2896}  float64
# 11            {'y': 600, 'x': 90}               {'y': 90, 'x': 144}  float32
# 12            {'y': 29, 'x': 600}             {'y': 600, 'x': 1440}  float32
# 13            {'y': 1, 'x': 1448}            {'y': 2896, 'x': 5792}  float64
# 14            {'y': 1, 'x': 1448}            {'y': 4096, 'x': 8192}  float64
# 15            {'y': 1, 'x': 1448}           {'y': 5793, 'x': 11586}  float64
# 16           {'y': 365, 'x': 262}             {'y': 600, 'x': 1440}  float32
# 17            {'y': 1, 'x': 2048}            {'y': 2048, 'x': 4096}  float64
# 18            {'y': 1, 'x': 2896}            {'y': 2896, 'x': 5792}  float64
# 19            {'y': 1, 'x': 4096}            {'y': 4096, 'x': 8192}  float64
# 20                            NaN                               NaN      NaN
#
#     chunk_size_mb                                        compression  \
# 0        4.000000  Blosc(cname='lz4', clevel=5, shuffle=SHUFFLE, ...
# 1        3.295898  Blosc(cname='lz4', clevel=5, shuffle=SHUFFLE, ...
# 2        3.295898                                      Zlib(level=5)
# 3        7.998291  Blosc(cname='lz4', clevel=5, shuffle=SHUFFLE, ...
# 4       16.000000  Blosc(cname='lz4', clevel=5, shuffle=SHUFFLE, ...
# 5       31.993164  Blosc(cname='lz4', clevel=5, shuffle=SHUFFLE, ...
# 6        2.403259  Blosc(cname='lz4', clevel=5, shuffle=SHUFFLE, ...
# 7             NaN                                                NaN
# 8        1.977539                                      Zlib(level=4)
# 9       31.993164  Blosc(cname='lz4', clevel=5, shuffle=SHUFFLE, ...
# 10      31.993164  Blosc(cname='lz4', clevel=5, shuffle=SHUFFLE, ...
# 11      29.663086  Blosc(cname='lz4', clevel=5, shuffle=SHUFFLE, ...
# 12      95.581055  Blosc(cname='lz4', clevel=5, shuffle=SHUFFLE, ...
# 13      31.993164  Blosc(cname='lz4', clevel=5, shuffle=SHUFFLE, ...
# 14      31.993164  Blosc(cname='lz4', clevel=5, shuffle=SHUFFLE, ...
# 15      31.993164  Blosc(cname='lz4', clevel=5, shuffle=SHUFFLE, ...
# 16      95.577469  Blosc(cname='lz4', clevel=5, shuffle=SHUFFLE, ...
# 17      64.000000  Blosc(cname='lz4', clevel=5, shuffle=SHUFFLE, ...
# 18     127.972656  Blosc(cname='lz4', clevel=5, shuffle=SHUFFLE, ...
# 19     256.000000  Blosc(cname='lz4', clevel=5, shuffle=SHUFFLE, ...
# 20            NaN                                                NaN
#
#     number_of_spatial_chunks  number_coordinate_chunks
# 0                1024.000000                       2.0
# 1                1440.000000                       1.0
# 2                1440.000000                       1.0
# 3                1448.000000                       2.0
# 4                2048.000000                       2.0
# 5                5793.237569                       2.0
# 6                  16.502857                       2.0
# 7                        NaN                       0.0
# 8                1440.000000                       2.0
# 9                2896.000000                       2.0
# 10               2896.000000                       2.0
# 11                  0.240000                       1.0
# 12                 49.655172                       1.0
# 13              11584.000000                       2.0
# 14              23172.950276                       2.0
# 15              46352.001381                       2.0
# 16                  9.034822                       1.0
# 17               4096.000000                       2.0
# 18               5792.000000                       2.0
# 19               8192.000000                       2.0
# 20                       NaN                       NaN

# %% [markdown]
# NOTE: We don't have chunk information for prod giovanni cache dataset since it is protected (it can be added).

# %%
dev_line = merged_specs.sort_values('chunk_size_mb').hvplot.line(
    x='chunk_size_mb', y='Average Response Time Dev', label='Dev', color='cyan',
    xlim=(0, 150), ylim=(0, 3000)
)

# Plot 'col2'
feature_line = merged_specs.sort_values('chunk_size_mb').hvplot.line(
    x='chunk_size_mb', y='Average Response Time Feature', label='Feature', color='magenta', alpha=0.4,
    xlim=(0, 150), ylim=(0, 3000)
)

# Combine the two line plots
combined_plot = dev_line * feature_line
combined_plot
# Out:
# :Overlay
#    .Curve.Dev     :Curve   [chunk_size_mb]   (Average Response Time Dev)
#    .Curve.Feature :Curve   [chunk_size_mb]   (Average Response Time Feature)
