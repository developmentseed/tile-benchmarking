# %%
import pandas as pd
import numpy as np
import os
from helpers import csv_to_pandas, download_results

# %%
download_results()
# Out:
# Downloading tile-benchmarking-results/latest/365_262_262_CMIP6_daily_GISS-E2-1-G_tas.zarr_urls_exceptions.csv to downloaded_results/365_262_262_CMIP6_daily_GISS-E2-1-G_tas.zarr_urls_exceptions.csv
# Downloading tile-benchmarking-results/latest/365_262_262_CMIP6_daily_GISS-E2-1-G_tas.zarr_urls_failures.csv to downloaded_results/365_262_262_CMIP6_daily_GISS-E2-1-G_tas.zarr_urls_failures.csv
# Downloading tile-benchmarking-results/latest/365_262_262_CMIP6_daily_GISS-E2-1-G_tas.zarr_urls_stats.csv to downloaded_results/365_262_262_CMIP6_daily_GISS-E2-1-G_tas.zarr_urls_stats.csv
# Downloading tile-benchmarking-results/latest/365_262_262_CMIP6_daily_GISS-E2-1-G_tas.zarr_urls_stats_history.csv to downloaded_results/365_262_262_CMIP6_daily_GISS-E2-1-G_tas.zarr_urls_stats_history.csv
# Downloading tile-benchmarking-results/latest/600_1440_1_CMIP6_daily_GISS-E2-1-G_tas.zarr_urls_exceptions.csv to downloaded_results/600_1440_1_CMIP6_daily_GISS-E2-1-G_tas.zarr_urls_exceptions.csv
# Downloading tile-benchmarking-results/latest/600_1440_1_CMIP6_daily_GISS-E2-1-G_tas.zarr_urls_failures.csv to downloaded_results/600_1440_1_CMIP6_daily_GISS-E2-1-G_tas.zarr_urls_failures.csv
# Downloading tile-benchmarking-results/latest/600_1440_1_CMIP6_daily_GISS-E2-1-G_tas.zarr_urls_stats.csv to downloaded_results/600_1440_1_CMIP6_daily_GISS-E2-1-G_tas.zarr_urls_stats.csv
# Downloading tile-benchmarking-results/latest/600_1440_1_CMIP6_daily_GISS-E2-1-G_tas.zarr_urls_stats_history.csv to downloaded_results/600_1440_1_CMIP6_daily_GISS-E2-1-G_tas.zarr_urls_stats_history.csv
# Downloading tile-benchmarking-results/latest/600_1440_29_CMIP6_daily_GISS-E2-1-G_tas.zarr_urls_exceptions.csv to downloaded_results/600_1440_29_CMIP6_daily_GISS-E2-1-G_tas.zarr_urls_exceptions.csv
# Downloading tile-benchmarking-results/latest/600_1440_29_CMIP6_daily_GISS-E2-1-G_tas.zarr_urls_failures.csv to downloaded_results/600_1440_29_CMIP6_daily_GISS-E2-1-G_tas.zarr_urls_failures.csv
# Downloading tile-benchmarking-results/latest/600_1440_29_CMIP6_daily_GISS-E2-1-G_tas.zarr_urls_stats.csv to downloaded_results/600_1440_29_CMIP6_daily_GISS-E2-1-G_tas.zarr_urls_stats.csv
# Downloading tile-benchmarking-results/latest/600_1440_29_CMIP6_daily_GISS-E2-1-G_tas.zarr_urls_stats_history.csv to downloaded_results/600_1440_29_CMIP6_daily_GISS-E2-1-G_tas.zarr_urls_stats_history.csv
# Downloading tile-benchmarking-results/latest/aws-noaa-oisst-feedstock_reference_urls_exceptions.csv to downloaded_results/aws-noaa-oisst-feedstock_reference_urls_exceptions.csv
# Downloading tile-benchmarking-results/latest/aws-noaa-oisst-feedstock_reference_urls_failures.csv to downloaded_results/aws-noaa-oisst-feedstock_reference_urls_failures.csv
# Downloading tile-benchmarking-results/latest/aws-noaa-oisst-feedstock_reference_urls_stats.csv to downloaded_results/aws-noaa-oisst-feedstock_reference_urls_stats.csv
# Downloading tile-benchmarking-results/latest/aws-noaa-oisst-feedstock_reference_urls_stats_history.csv to downloaded_results/aws-noaa-oisst-feedstock_reference_urls_stats_history.csv
# Downloading tile-benchmarking-results/latest/cmip6-kerchunk_urls_exceptions.csv to downloaded_results/cmip6-kerchunk_urls_exceptions.csv
# Downloading tile-benchmarking-results/latest/cmip6-kerchunk_urls_failures.csv to downloaded_results/cmip6-kerchunk_urls_failures.csv
# Downloading tile-benchmarking-results/latest/cmip6-kerchunk_urls_stats.csv to downloaded_results/cmip6-kerchunk_urls_stats.csv
# Downloading tile-benchmarking-results/latest/cmip6-kerchunk_urls_stats_history.csv to downloaded_results/cmip6-kerchunk_urls_stats_history.csv
# Downloading tile-benchmarking-results/latest/cmip6-pds_GISS-E2-1-G_historical_tas_urls_exceptions.csv to downloaded_results/cmip6-pds_GISS-E2-1-G_historical_tas_urls_exceptions.csv
# Downloading tile-benchmarking-results/latest/cmip6-pds_GISS-E2-1-G_historical_tas_urls_failures.csv to downloaded_results/cmip6-pds_GISS-E2-1-G_historical_tas_urls_failures.csv
# Downloading tile-benchmarking-results/latest/cmip6-pds_GISS-E2-1-G_historical_tas_urls_stats.csv to downloaded_results/cmip6-pds_GISS-E2-1-G_historical_tas_urls_stats.csv
# Downloading tile-benchmarking-results/latest/cmip6-pds_GISS-E2-1-G_historical_tas_urls_stats_history.csv to downloaded_results/cmip6-pds_GISS-E2-1-G_historical_tas_urls_stats_history.csv
# Downloading tile-benchmarking-results/latest/power_901_monthly_meteorology_utc.zarr_urls_exceptions.csv to downloaded_results/power_901_monthly_meteorology_utc.zarr_urls_exceptions.csv
# Downloading tile-benchmarking-results/latest/power_901_monthly_meteorology_utc.zarr_urls_failures.csv to downloaded_results/power_901_monthly_meteorology_utc.zarr_urls_failures.csv
# Downloading tile-benchmarking-results/latest/power_901_monthly_meteorology_utc.zarr_urls_stats.csv to downloaded_results/power_901_monthly_meteorology_utc.zarr_urls_stats.csv
# Downloading tile-benchmarking-results/latest/power_901_monthly_meteorology_utc.zarr_urls_stats_history.csv to downloaded_results/power_901_monthly_meteorology_utc.zarr_urls_stats_history.csv
# Download completed.

# %%
dataset_specs_all = csv_to_pandas('zarr_info.csv')
dataset_specs_all.index = dataset_specs_all['collection_name']
ds_specs = dataset_specs_all[['chunks', 'shape_dict', 'chunk_size_mb', 'number_coordinate_chunks', 'number_of_spatial_chunks']]
ds_specs
# Out:
#                                                                                        chunks  \
# collection_name
# power_901_monthly_meteorology_utc.zarr                    {'time': 492, 'lat': 25, 'lon': 25}
# cmip6-pds_GISS-E2-1-G_historical_tas                     {'time': 600, 'lat': 90, 'lon': 144}
# aws-noaa-oisst-feedstock_reference            {'time': 1, 'zlev': 1, 'lat': 720, 'lon': 1440}
# 600_1440_29_CMIP6_daily_GISS-E2-1-G_tas.zarr            {'time': 29, 'lat': 600, 'lon': 1440}
# 600_1440_1_CMIP6_daily_GISS-E2-1-G_tas.zarr              {'time': 1, 'lat': 600, 'lon': 1440}
# 365_262_262_CMIP6_daily_GISS-E2-1-G_tas.zarr            {'time': 365, 'lat': 262, 'lon': 262}
# cmip6-kerchunk                                           {'time': 1, 'lat': 600, 'lon': 1440}
#
#                                                                                      shape_dict  \
# collection_name
# power_901_monthly_meteorology_utc.zarr                    {'time': 492, 'lat': 361, 'lon': 576}
# cmip6-pds_GISS-E2-1-G_historical_tas                      {'time': 1980, 'lat': 90, 'lon': 144}
# aws-noaa-oisst-feedstock_reference            {'time': 15044, 'zlev': 1, 'lat': 720, 'lon': ...
# 600_1440_29_CMIP6_daily_GISS-E2-1-G_tas.zarr             {'time': 730, 'lat': 600, 'lon': 1440}
# 600_1440_1_CMIP6_daily_GISS-E2-1-G_tas.zarr              {'time': 730, 'lat': 600, 'lon': 1440}
# 365_262_262_CMIP6_daily_GISS-E2-1-G_tas.zarr             {'time': 730, 'lat': 600, 'lon': 1440}
# cmip6-kerchunk                                           {'time': 730, 'lat': 600, 'lon': 1440}
#
#                                               chunk_size_mb  \
# collection_name
# power_901_monthly_meteorology_utc.zarr             2.346039
# cmip6-pds_GISS-E2-1-G_historical_tas              29.663086
# aws-noaa-oisst-feedstock_reference                 1.977539
# 600_1440_29_CMIP6_daily_GISS-E2-1-G_tas.zarr      95.581055
# 600_1440_1_CMIP6_daily_GISS-E2-1-G_tas.zarr        3.295898
# 365_262_262_CMIP6_daily_GISS-E2-1-G_tas.zarr      95.577469
# cmip6-kerchunk                                     3.295898
#
#                                               number_coordinate_chunks  \
# collection_name
# power_901_monthly_meteorology_utc.zarr                              43
# cmip6-pds_GISS-E2-1-G_historical_tas                                 6
# aws-noaa-oisst-feedstock_reference                                   4
# 600_1440_29_CMIP6_daily_GISS-E2-1-G_tas.zarr                         3
# 600_1440_1_CMIP6_daily_GISS-E2-1-G_tas.zarr                          3
# 365_262_262_CMIP6_daily_GISS-E2-1-G_tas.zarr                         3
# cmip6-kerchunk                                                       3
#
#                                               number_of_spatial_chunks
# collection_name
# power_901_monthly_meteorology_utc.zarr                      332.697600
# cmip6-pds_GISS-E2-1-G_historical_tas                          1.000000
# aws-noaa-oisst-feedstock_reference                            1.000000
# 600_1440_29_CMIP6_daily_GISS-E2-1-G_tas.zarr                  1.000000
# 600_1440_1_CMIP6_daily_GISS-E2-1-G_tas.zarr                   1.000000
# 365_262_262_CMIP6_daily_GISS-E2-1-G_tas.zarr                 12.586679
# cmip6-kerchunk                                                1.000000

# %%
for collection_name in ds_specs.index:
    file_path = f'downloaded_results/{collection_name}_urls_stats.csv'
    if os.path.exists(file_path):
        results_df = csv_to_pandas(file_path)
        ds_specs.loc[collection_name, 'median response time (all tiles)'] = float(results_df[(results_df['Name'] == 'Aggregated')]['Median Response Time'])
        ds_specs.loc[collection_name, 'average response time (all tiles)'] = float(results_df[(results_df['Name'] == 'Aggregated')]['Average Response Time'])
        # skip the last row which is the "Aggregated"
        zooms = []
        for path in results_df['Name']:
            paths = path.split('/')
            if len(paths) > 2:
                zooms.append(paths[2])
            else:
                zooms.append('N/A')
        results_df['zoom'] = zooms
        zero_tile_results = results_df[results_df['zoom'] == '0']
        six_tile_results = results_df[results_df['zoom'] == '5']
        ds_specs.loc[collection_name, 'mean median response time - tile 0'] = np.mean(zero_tile_results['Median Response Time'])
        ds_specs.loc[collection_name, 'mean median response time - tile 5'] = np.mean(six_tile_results['Median Response Time'])        

ds_specs
# Out:
# /var/folders/jh/_03qbqf130l8hjh8rpc6f4_c0000gn/T/ipykernel_74727/219231912.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ds_specs.loc[collection_name, 'median response time (all tiles)'] = float(results_df[(results_df['Name'] == 'Aggregated')]['Median Response Time'])
# /var/folders/jh/_03qbqf130l8hjh8rpc6f4_c0000gn/T/ipykernel_74727/219231912.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ds_specs.loc[collection_name, 'average response time (all tiles)'] = float(results_df[(results_df['Name'] == 'Aggregated')]['Average Response Time'])
# /var/folders/jh/_03qbqf130l8hjh8rpc6f4_c0000gn/T/ipykernel_74727/219231912.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ds_specs.loc[collection_name, 'mean median response time - tile 0'] = np.mean(zero_tile_results['Median Response Time'])
#                                                                                        chunks  \
# collection_name
# power_901_monthly_meteorology_utc.zarr                    {'time': 492, 'lat': 25, 'lon': 25}
# cmip6-pds_GISS-E2-1-G_historical_tas                     {'time': 600, 'lat': 90, 'lon': 144}
# aws-noaa-oisst-feedstock_reference            {'time': 1, 'zlev': 1, 'lat': 720, 'lon': 1440}
# 600_1440_29_CMIP6_daily_GISS-E2-1-G_tas.zarr            {'time': 29, 'lat': 600, 'lon': 1440}
# 600_1440_1_CMIP6_daily_GISS-E2-1-G_tas.zarr              {'time': 1, 'lat': 600, 'lon': 1440}
# 365_262_262_CMIP6_daily_GISS-E2-1-G_tas.zarr            {'time': 365, 'lat': 262, 'lon': 262}
# cmip6-kerchunk                                           {'time': 1, 'lat': 600, 'lon': 1440}
#
#                                                                                      shape_dict  \
# collection_name
# power_901_monthly_meteorology_utc.zarr                    {'time': 492, 'lat': 361, 'lon': 576}
# cmip6-pds_GISS-E2-1-G_historical_tas                      {'time': 1980, 'lat': 90, 'lon': 144}
# aws-noaa-oisst-feedstock_reference            {'time': 15044, 'zlev': 1, 'lat': 720, 'lon': ...
# 600_1440_29_CMIP6_daily_GISS-E2-1-G_tas.zarr             {'time': 730, 'lat': 600, 'lon': 1440}
# 600_1440_1_CMIP6_daily_GISS-E2-1-G_tas.zarr              {'time': 730, 'lat': 600, 'lon': 1440}
# 365_262_262_CMIP6_daily_GISS-E2-1-G_tas.zarr             {'time': 730, 'lat': 600, 'lon': 1440}
# cmip6-kerchunk                                           {'time': 730, 'lat': 600, 'lon': 1440}
#
#                                               chunk_size_mb  \
# collection_name
# power_901_monthly_meteorology_utc.zarr             2.346039
# cmip6-pds_GISS-E2-1-G_historical_tas              29.663086
# aws-noaa-oisst-feedstock_reference                 1.977539
# 600_1440_29_CMIP6_daily_GISS-E2-1-G_tas.zarr      95.581055
# 600_1440_1_CMIP6_daily_GISS-E2-1-G_tas.zarr        3.295898
# 365_262_262_CMIP6_daily_GISS-E2-1-G_tas.zarr      95.577469
# cmip6-kerchunk                                     3.295898
#
#                                               number_coordinate_chunks  \
# collection_name
# power_901_monthly_meteorology_utc.zarr                              43
# cmip6-pds_GISS-E2-1-G_historical_tas                                 6
# aws-noaa-oisst-feedstock_reference                                   4
# 600_1440_29_CMIP6_daily_GISS-E2-1-G_tas.zarr                         3
# 600_1440_1_CMIP6_daily_GISS-E2-1-G_tas.zarr                          3
# 365_262_262_CMIP6_daily_GISS-E2-1-G_tas.zarr                         3
# cmip6-kerchunk                                                       3
#
#                                               number_of_spatial_chunks  \
# collection_name
# power_901_monthly_meteorology_utc.zarr                      332.697600
# cmip6-pds_GISS-E2-1-G_historical_tas                          1.000000
# aws-noaa-oisst-feedstock_reference                            1.000000
# 600_1440_29_CMIP6_daily_GISS-E2-1-G_tas.zarr                  1.000000
# 600_1440_1_CMIP6_daily_GISS-E2-1-G_tas.zarr                   1.000000
# 365_262_262_CMIP6_daily_GISS-E2-1-G_tas.zarr                 12.586679
# cmip6-kerchunk                                                1.000000
#
#                                               median response time (all tiles)  \
# collection_name
# power_901_monthly_meteorology_utc.zarr                                   420.0
# cmip6-pds_GISS-E2-1-G_historical_tas                                     460.0
# aws-noaa-oisst-feedstock_reference                                       430.0
# 600_1440_29_CMIP6_daily_GISS-E2-1-G_tas.zarr                             520.0
# 600_1440_1_CMIP6_daily_GISS-E2-1-G_tas.zarr                              240.0
# 365_262_262_CMIP6_daily_GISS-E2-1-G_tas.zarr                             450.0
# cmip6-kerchunk                                                           230.0
#
#                                               average response time (all tiles)  \
# collection_name
# power_901_monthly_meteorology_utc.zarr                               492.183299
# cmip6-pds_GISS-E2-1-G_historical_tas                                 472.943814
# aws-noaa-oisst-feedstock_reference                                   467.583357
# 600_1440_29_CMIP6_daily_GISS-E2-1-G_tas.zarr                         425.108589
# 600_1440_1_CMIP6_daily_GISS-E2-1-G_tas.zarr                          230.765718
# 365_262_262_CMIP6_daily_GISS-E2-1-G_tas.zarr                         544.150062
# cmip6-kerchunk                                                       222.519445
#
#                                               mean median response time - tile 0  \
# collection_name
# power_901_monthly_meteorology_utc.zarr                               4727.959961
# cmip6-pds_GISS-E2-1-G_historical_tas                                 1007.719311
# aws-noaa-oisst-feedstock_reference                                   3281.720884
# 600_1440_29_CMIP6_daily_GISS-E2-1-G_tas.zarr                         1168.950803
# 600_1440_1_CMIP6_daily_GISS-E2-1-G_tas.zarr                           722.530947
# 365_262_262_CMIP6_daily_GISS-E2-1-G_tas.zarr                         7971.013376
# cmip6-kerchunk                                                        995.688512
#
#                                               mean median response time - tile 5
# collection_name
# power_901_monthly_meteorology_utc.zarr                                409.857732
# cmip6-pds_GISS-E2-1-G_historical_tas                                  464.813854
# aws-noaa-oisst-feedstock_reference                                    424.062792
# 600_1440_29_CMIP6_daily_GISS-E2-1-G_tas.zarr                          363.565574
# 600_1440_1_CMIP6_daily_GISS-E2-1-G_tas.zarr                           232.008550
# 365_262_262_CMIP6_daily_GISS-E2-1-G_tas.zarr                          463.325554
# cmip6-kerchunk                                                        212.379288
