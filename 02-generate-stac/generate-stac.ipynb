# %%
# %%capture
# !pip install xstac

# %%
# List all zarr data in test-data
# %load_ext autoreload
# %autoreload
import json
import pystac
from pystac_client import Client
import s3fs
import sys; sys.path.append('..');
import helpers.eodc_hub_role as eodc_hub_role
import helpers.s3helpers as s3helpers
import helpers.stac as stachelpers
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
credentials = eodc_hub_role.fetch_and_set_credentials()
bucket = 'nasa-eodc-data-store'
prefix = "test-data"
s3_fs = s3fs.S3FileSystem(
    key=credentials['AccessKeyId'],
    secret=credentials['SecretAccessKey'],
    token=credentials['SessionToken'], 
    anon=False
)

# %%
# Create a new STAC Catalog
stac_catalog = pystac.Catalog(
    id='eodc-data-store-for-zarr-viz',
    description='EODC Data Store for Zarr Viz'
)

# %%
suffixes = [".zarr", ".json"]
matching_paths = s3helpers.list_s3_paths(bucket, prefix, suffixes)

for path in matching_paths:
    print(path)
# Out:
# nasa-eodc-data-store/test-data/cmip6-kerchunk/combined_CMIP6_daily_GISS-E2-1-G_tas_kerchunk.json
# nasa-eodc-data-store/test-data/cmip6-zarr/365_262_262_CMIP6_daily_GISS-E2-1-G_tas.zarr
# nasa-eodc-data-store/test-data/cmip6-zarr/600_1440_1_CMIP6_daily_GISS-E2-1-G_tas.zarr
# nasa-eodc-data-store/test-data/cmip6-zarr/600_1440_29_CMIP6_daily_GISS-E2-1-G_tas.zarr
# nasa-eodc-data-store/test-data/fake-data/single_chunk/store_lat1024_lon2048.zarr
# nasa-eodc-data-store/test-data/fake-data/single_chunk/store_lat1448_lon2896.zarr
# nasa-eodc-data-store/test-data/fake-data/single_chunk/store_lat2048_lon4096.zarr
# nasa-eodc-data-store/test-data/fake-data/single_chunk/store_lat2896_lon5792.zarr
# nasa-eodc-data-store/test-data/fake-data/single_chunk/store_lat4096_lon8192.zarr
# nasa-eodc-data-store/test-data/fake-data/single_chunk/store_lat512_lon1024.zarr
# nasa-eodc-data-store/test-data/fake-data/single_chunk/store_lat724_lon1448.zarr
# nasa-eodc-data-store/test-data/fake-data/with_chunks/store_lat1448_lon2896.zarr
# nasa-eodc-data-store/test-data/fake-data/with_chunks/store_lat2048_lon4096.zarr
# nasa-eodc-data-store/test-data/fake-data/with_chunks/store_lat2896_lon5792.zarr
# nasa-eodc-data-store/test-data/fake-data/with_chunks/store_lat4096_lon8192.zarr
# nasa-eodc-data-store/test-data/fake-data/with_chunks/store_lat5793_lon11586.zarr

# %%
for path in matching_paths:
    reference = False
    if path.endswith('.json'):
        reference = True
    stac_collection = stachelpers.generate_stac(f's3://{path}', reference=reference)
    stac_collection.links = [pystac.Link(target="collection.json", rel="self")]
    stac_catalog.add_child(stac_collection)
# Out:
# /home/jovyan/tile-benchmarking/02-generate-stac/../titiler_xarray/titiler/xarray/reader.py:45: UserWarning: Variable(s) referenced in cell_measures not in variables: ['areacella']
#   return xarray.open_dataset(src_path, **xr_open_args)
# /home/jovyan/tile-benchmarking/02-generate-stac/../titiler_xarray/titiler/xarray/reader.py:45: UserWarning: Variable(s) referenced in cell_measures not in variables: ['areacella']
#   return xarray.open_dataset(src_path, **xr_open_args)
# /home/jovyan/tile-benchmarking/02-generate-stac/../titiler_xarray/titiler/xarray/reader.py:45: UserWarning: Variable(s) referenced in cell_measures not in variables: ['areacella']
#   return xarray.open_dataset(src_path, **xr_open_args)
# /home/jovyan/tile-benchmarking/02-generate-stac/../titiler_xarray/titiler/xarray/reader.py:45: UserWarning: Variable(s) referenced in cell_measures not in variables: ['areacella']
#   return xarray.open_dataset(src_path, **xr_open_args)

# %%
with open('external-datasets.json', 'r') as f:
    external_datasets = json.loads(f.read())

for key, dataset in external_datasets.items():
    reference = False
    path = dataset['source']
    if path.endswith('.json'):
        reference = True
    stac_collection = stachelpers.generate_stac(path, idstr=key, reference=reference)
    stac_collection.links = [pystac.Link(target="collection.json", rel="self")]
    stac_catalog.add_child(stac_collection)
# Out:
# /home/jovyan/tile-benchmarking/02-generate-stac/../titiler_xarray/titiler/xarray/reader.py:45: UserWarning: Variable(s) referenced in cell_measures not in variables: ['areacella']
#   return xarray.open_dataset(src_path, **xr_open_args)

# %%
stac_catalog
# Out:
# <Catalog id=eodc-data-store-for-zarr-viz>

# %%
stac_catalog.normalize_and_save(root_href="stac")

# %%
stac_catalog.save(pystac.CatalogType.SELF_CONTAINED)

# %%
STAC_API_URL = "stac/catalog.json"
catalog = Client.open(STAC_API_URL)

# %%
collections = list(catalog.get_collections())
for collection in sorted(collections, key=lambda x: x.id):
    print(collection.summaries.to_dict())
# Out:
# {'other': {'number_coord_chunks': 3, 'tas': {'chunks': [365, 262, 262], 'dtype': 'float32', 'chunk_size_mb': 95.57746887207031, 'compression': "Blosc(cname='lz4', clevel=5, shuffle=SHUFFLE, blocksize=0)", 'total_array_size': 2406.005859375}}}
# {'other': {'number_coord_chunks': 3, 'tas': {'chunks': [365, 262, 262], 'dtype': 'float32', 'chunk_size_mb': 95.57746887207031, 'compression': "Blosc(cname='lz4', clevel=5, shuffle=SHUFFLE, blocksize=0)", 'total_array_size': 2406.005859375}}}
# {'other': {'number_coord_chunks': 3, 'tas': {'chunks': [1, 600, 1440], 'dtype': 'float32', 'chunk_size_mb': 3.2958984375, 'compression': "Blosc(cname='lz4', clevel=5, shuffle=SHUFFLE, blocksize=0)", 'total_array_size': 2406.005859375}}}
# {'other': {'number_coord_chunks': 3, 'tas': {'chunks': [1, 600, 1440], 'dtype': 'float32', 'chunk_size_mb': 3.2958984375, 'compression': "Blosc(cname='lz4', clevel=5, shuffle=SHUFFLE, blocksize=0)", 'total_array_size': 2406.005859375}}}
# {'other': {'number_coord_chunks': 3, 'tas': {'chunks': [29, 600, 1440], 'dtype': 'float32', 'chunk_size_mb': 95.5810546875, 'compression': "Blosc(cname='lz4', clevel=5, shuffle=SHUFFLE, blocksize=0)", 'total_array_size': 2406.005859375}}}
# {'other': {'number_coord_chunks': 3, 'tas': {'chunks': [29, 600, 1440], 'dtype': 'float32', 'chunk_size_mb': 95.5810546875, 'compression': "Blosc(cname='lz4', clevel=5, shuffle=SHUFFLE, blocksize=0)", 'total_array_size': 2406.005859375}}}
# {'other': {'number_coord_chunks': 4, 'ice': {'chunks': [1, 1, 720, 1440], 'dtype': 'int16', 'chunk_size_mb': 1.9775390625, 'compression': 'Zlib(level=4)', 'total_array_size': 29750.09765625}, 'err': {'chunks': [1, 1, 720, 1440], 'dtype': 'int16', 'chunk_size_mb': 1.9775390625, 'compression': 'Zlib(level=4)', 'total_array_size': 29750.09765625}, 'sst': {'chunks': [1, 1, 720, 1440], 'dtype': 'int16', 'chunk_size_mb': 1.9775390625, 'compression': 'Zlib(level=4)', 'total_array_size': 29750.09765625}, 'anom': {'chunks': [1, 1, 720, 1440], 'dtype': 'int16', 'chunk_size_mb': 1.9775390625, 'compression': 'Zlib(level=4)', 'total_array_size': 29750.09765625}}}
# {'other': {'number_coord_chunks': 6, 'lon_bnds': {'chunks': [144, 2], 'dtype': 'float64', 'chunk_size_mb': 0.002197265625, 'compression': "Blosc(cname='lz4', clevel=5, shuffle=SHUFFLE, blocksize=0)", 'total_array_size': 0.002197265625}, 'lat_bnds': {'chunks': [90, 2], 'dtype': 'float64', 'chunk_size_mb': 0.001373291015625, 'compression': "Blosc(cname='lz4', clevel=5, shuffle=SHUFFLE, blocksize=0)", 'total_array_size': 0.001373291015625}, 'height': {'chunks': [], 'dtype': 'float64', 'chunk_size_mb': 7.62939453125e-06, 'compression': 'None', 'total_array_size': 7.62939453125e-06}, 'tas': {'chunks': [600, 90, 144], 'dtype': 'float32', 'chunk_size_mb': 29.6630859375, 'compression': "Blosc(cname='lz4', clevel=5, shuffle=SHUFFLE, blocksize=0)", 'total_array_size': 97.88818359375}, 'time_bnds': {'chunks': [1980, 2], 'dtype': 'float64', 'chunk_size_mb': 0.03021240234375, 'compression': "Blosc(cname='lz4', clevel=5, shuffle=SHUFFLE, blocksize=0)", 'total_array_size': 0.03021240234375}}}
# {'other': {'number_coord_chunks': 3, 'tas': {'chunks': [1, 600, 1440], 'dtype': 'float32', 'chunk_size_mb': 3.2958984375, 'compression': 'Zlib(level=5)', 'total_array_size': 2406.005859375}}}
# {'other': {'number_coord_chunks': 3, 'tas': {'chunks': [1, 600, 1440], 'dtype': 'float32', 'chunk_size_mb': 3.2958984375, 'compression': 'Zlib(level=5)', 'total_array_size': 2406.005859375}}}
# {'other': {'number_coord_chunks': 43, 'GWETROOT': {'chunks': [492, 25, 25], 'dtype': 'float64', 'chunk_size_mb': 2.346038818359375, 'compression': "Blosc(cname='lz4', clevel=5, shuffle=SHUFFLE, blocksize=0)", 'total_array_size': 780.521484375}, 'WS2M_MAX': {'chunks': [492, 25, 25], 'dtype': 'float64', 'chunk_size_mb': 2.346038818359375, 'compression': "Blosc(cname='lz4', clevel=5, shuffle=SHUFFLE, blocksize=0)", 'total_array_size': 780.521484375}, 'T2MDEW': {'chunks': [492, 25, 25], 'dtype': 'float64', 'chunk_size_mb': 2.346038818359375, 'compression': "Blosc(cname='lz4', clevel=5, shuffle=SHUFFLE, blocksize=0)", 'total_array_size': 780.521484375}, 'U10M': {'chunks': [492, 25, 25], 'dtype': 'float64', 'chunk_size_mb': 2.346038818359375, 'compression': "Blosc(cname='lz4', clevel=5, shuffle=SHUFFLE, blocksize=0)", 'total_array_size': 780.521484375}, 'T2M_MAX_AVG': {'chunks': [492, 25, 25], 'dtype': 'float64', 'chunk_size_mb': 2.346038818359375, 'compression': "Blosc(cname='lz4', clevel=5, shuffle=SHUFFLE, blocksize=0)", 'total_array_size': 780.521484375}, 'WS50M_MIN': {'chunks': [492, 25, 25], 'dtype': 'float64', 'chunk_size_mb': 2.346038818359375, 'compression': "Blosc(cname='lz4', clevel=5, shuffle=SHUFFLE, blocksize=0)", 'total_array_size': 780.521484375}, 'TS_RANGE': {'chunks': [492, 25, 25], 'dtype': 'float64', 'chunk_size_mb': 2.346038818359375, 'compression': "Blosc(cname='lz4', clevel=5, shuffle=SHUFFLE, blocksize=0)", 'total_array_size': 780.521484375}, 'WS2M': {'chunks': [492, 25, 25], 'dtype': 'float64', 'chunk_size_mb': 2.346038818359375, 'compression': "Blosc(cname='lz4', clevel=5, shuffle=SHUFFLE, blocksize=0)", 'total_array_size': 780.521484375}, 'FROST_DAYS': {'chunks': [62, 46, 72], 'dtype': 'int64', 'chunk_size_mb': 1.566650390625, 'compression': "Blosc(cname='lz4', clevel=5, shuffle=SHUFFLE, blocksize=0)", 'total_array_size': 780.521484375}, 'WS50M': {'chunks': [492, 25, 25], 'dtype': 'float64', 'chunk_size_mb': 2.346038818359375, 'compression': "Blosc(cname='lz4', clevel=5, shuffle=SHUFFLE, blocksize=0)", 'total_array_size': 780.521484375}, 'TS_MAX': {'chunks': [492, 25, 25], 'dtype': 'float64', 'chunk_size_mb': 2.346038818359375, 'compression': "Blosc(cname='lz4', clevel=5, shuffle=SHUFFLE, blocksize=0)", 'total_array_size': 780.521484375}, 'TROPPB': {'chunks': [492, 25, 25], 'dtype': 'float64', 'chunk_size_mb': 2.346038818359375, 'compression': "Blosc(cname='lz4', clevel=5, shuffle=SHUFFLE, blocksize=0)", 'total_array_size': 780.521484375}, 'WD10M': {'chunks': [492, 25, 25], 'dtype': 'float64', 'chunk_size_mb': 2.346038818359375, 'compression': "Blosc(cname='lz4', clevel=5, shuffle=SHUFFLE, blocksize=0)", 'total_array_size': 780.521484375}, 'T2MWET': {'chunks': [492, 25, 25], 'dtype': 'float64', 'chunk_size_mb': 2.346038818359375, 'compression': "Blosc(cname='lz4', clevel=5, shuffle=SHUFFLE, blocksize=0)", 'total_array_size': 780.521484375}, 'WS2M_MAX_AVG': {'chunks': [492, 25, 25], 'dtype': 'float64', 'chunk_size_mb': 2.346038818359375, 'compression': "Blosc(cname='lz4', clevel=5, shuffle=SHUFFLE, blocksize=0)", 'total_array_size': 780.521484375}, 'TS_MIN': {'chunks': [492, 25, 25], 'dtype': 'float64', 'chunk_size_mb': 2.346038818359375, 'compression': "Blosc(cname='lz4', clevel=5, shuffle=SHUFFLE, blocksize=0)", 'total_array_size': 780.521484375}, 'T2M_MAX': {'chunks': [492, 25, 25], 'dtype': 'float64', 'chunk_size_mb': 2.346038818359375, 'compression': "Blosc(cname='lz4', clevel=5, shuffle=SHUFFLE, blocksize=0)", 'total_array_size': 780.521484375}, 'T10M': {'chunks': [492, 25, 25], 'dtype': 'float64', 'chunk_size_mb': 2.346038818359375, 'compression': "Blosc(cname='lz4', clevel=5, shuffle=SHUFFLE, blocksize=0)", 'total_array_size': 780.521484375}, 'PRECSNO': {'chunks': [492, 25, 25], 'dtype': 'float64', 'chunk_size_mb': 2.346038818359375, 'compression': "Blosc(cname='lz4', clevel=5, shuffle=SHUFFLE, blocksize=0)", 'total_array_size': 780.521484375}, 'PRECSNOLAND_SUM': {'chunks': [492, 25, 25], 'dtype': ' ...
# {'other': {'number_coord_chunks': 3, 'data': {'chunks': [1, 1024, 2048], 'dtype': 'float64', 'chunk_size_mb': 16.0, 'compression': "Blosc(cname='lz4', clevel=5, shuffle=SHUFFLE, blocksize=0)", 'total_array_size': 16.0}}}
# {'other': {'number_coord_chunks': 3, 'data': {'chunks': [1, 1024, 2048], 'dtype': 'float64', 'chunk_size_mb': 16.0, 'compression': "Blosc(cname='lz4', clevel=5, shuffle=SHUFFLE, blocksize=0)", 'total_array_size': 16.0}}}
# {'other': {'number_coord_chunks': 3, 'data': {'chunks': [1, 1448, 2896], 'dtype': 'float64', 'chunk_size_mb': 31.9931640625, 'compression': "Blosc(cname='lz4', clevel=5, shuffle=SHUFFLE, blocksize=0)", 'total_array_size': 31.9931640625}}}
# {'other': {'number_coord_chunks': 3, 'data': {'chunks': [1, 1448, 2896], 'dtype': 'float64', 'chunk_size_mb': 31.9931640625, 'compression': "Blosc(cname='lz4', clevel=5, shuffle=SHUFFLE, blocksize=0)", 'total_array_size': 31.9931640625}}}
# {'other': {'number_coord_chunks': 3, 'data': {'chunks': [1, 1448, 2896], 'dtype': 'float64', 'chunk_size_mb': 31.9931640625, 'compression': "Blosc(cname='lz4', clevel=5, shuffle=SHUFFLE, blocksize=0)", 'total_array_size': 31.9931640625}}}
# {'other': {'number_coord_chunks': 3, 'data': {'chunks': [1, 1448, 2896], 'dtype': 'float64', 'chunk_size_mb': 31.9931640625, 'compression': "Blosc(cname='lz4', clevel=5, shuffle=SHUFFLE, blocksize=0)", 'total_array_size': 31.9931640625}}}
# {'other': {'number_coord_chunks': 3, 'data': {'chunks': [1, 1448, 2896], 'dtype': 'float64', 'chunk_size_mb': 31.9931640625, 'compression': "Blosc(cname='lz4', clevel=5, shuffle=SHUFFLE, blocksize=0)", 'total_array_size': 64.0}}}
# {'other': {'number_coord_chunks': 3, 'data': {'chunks': [1, 1448, 2896], 'dtype': 'float64', 'chunk_size_mb': 31.9931640625, 'compression': "Blosc(cname='lz4', clevel=5, shuffle=SHUFFLE, blocksize=0)", 'total_array_size': 64.0}}}
# {'other': {'number_coord_chunks': 3, 'data': {'chunks': [1, 1448, 2896], 'dtype': 'float64', 'chunk_size_mb': 31.9931640625, 'compression': "Blosc(cname='lz4', clevel=5, shuffle=SHUFFLE, blocksize=0)", 'total_array_size': 64.0}}}
# {'other': {'number_coord_chunks': 3, 'data': {'chunks': [1, 1448, 2896], 'dtype': 'float64', 'chunk_size_mb': 31.9931640625, 'compression': "Blosc(cname='lz4', clevel=5, shuffle=SHUFFLE, blocksize=0)", 'total_array_size': 64.0}}}
# {'other': {'number_coord_chunks': 3, 'data': {'chunks': [1, 1448, 2896], 'dtype': 'float64', 'chunk_size_mb': 31.9931640625, 'compression': "Blosc(cname='lz4', clevel=5, shuffle=SHUFFLE, blocksize=0)", 'total_array_size': 127.97265625}}}
# {'other': {'number_coord_chunks': 3, 'data': {'chunks': [1, 1448, 2896], 'dtype': 'float64', 'chunk_size_mb': 31.9931640625, 'compression': "Blosc(cname='lz4', clevel=5, shuffle=SHUFFLE, blocksize=0)", 'total_array_size': 127.97265625}}}
# {'other': {'number_coord_chunks': 3, 'data': {'chunks': [1, 1448, 2896], 'dtype': 'float64', 'chunk_size_mb': 31.9931640625, 'compression': "Blosc(cname='lz4', clevel=5, shuffle=SHUFFLE, blocksize=0)", 'total_array_size': 127.97265625}}}
# {'other': {'number_coord_chunks': 3, 'data': {'chunks': [1, 1448, 2896], 'dtype': 'float64', 'chunk_size_mb': 31.9931640625, 'compression': "Blosc(cname='lz4', clevel=5, shuffle=SHUFFLE, blocksize=0)", 'total_array_size': 127.97265625}}}
# {'other': {'number_coord_chunks': 3, 'data': {'chunks': [1, 1448, 2896], 'dtype': 'float64', 'chunk_size_mb': 31.9931640625, 'compression': "Blosc(cname='lz4', clevel=5, shuffle=SHUFFLE, blocksize=0)", 'total_array_size': 256.0}}}
# {'other': {'number_coord_chunks': 3, 'data': {'chunks': [1, 1448, 2896], 'dtype': 'float64', 'chunk_size_mb': 31.9931640625, 'compression': "Blosc(cname='lz4', clevel=5, shuffle=SHUFFLE, blocksize=0)", 'total_array_size': 256.0}}}
# {'other': {'number_coord_chunks': 3, 'data': {'chunks': [1, 1448, 2896], 'dtype': 'float64', 'chunk_size_mb': 31.9931640625, 'compression': "Blosc(cname='lz4', clevel=5, shuffle=SHUFFLE, blocksize=0)", 'total_array_size': 256.0}}}
# {'other': {'number_coord_chunks': 3, 'data': {'chunks': [1, 1448, 2896], 'dtype': 'float64', 'chunk_size_mb': 31.9931640625, 'compression': "Blosc(cname='lz4', clevel=5, shuffle=SHUFFLE, blocksize=0)", 'total_array_size': 256.0}}}
# {'other': {'number_coord_chunks': 3, 'data': {'chunks': [1, 512, 1024], 'dtype': 'float64', 'chunk_size_mb': 4.0, 'compression': "Blosc(cname='lz4', clevel=5, shuffle=SHUFFLE, blocksize=0)", 'total_array_size': 4.0}}}
# {'other': {'number_coord_chunks': 3, 'data': {'chunks': [1, 512, 1024], 'dtype': 'float64', 'chunk_size_mb': 4.0, 'compression': "Blosc(cname='lz4', clevel=5, shuffle=SHUFFLE, blocksize=0)", 'total_array_size': 4.0}}}
# {'other': {'number_coord_chunks': 3, 'data': {'chunks': [1, 1448, 2896], 'dtype': 'float64', 'chunk_size_mb': 31.9931640625, 'compression': "Blosc(cname='lz4', clevel=5, shuffle=SHUFFLE, blocksize=0)", 'total_array_size': 512.0673980712891}}}
# {'other': {'number_coord_chunks': 3, 'data': {'chunks': [1, 1448, 2896], 'dtype': 'float64', 'chunk_size_mb': 31.9931640625, 'compression': "Blosc(cname='lz4', clevel=5, shuffle=SHUFFLE, blocksize=0)", 'total_array_size': 512.0673980712891}}}
# {'other': {'number_coord_chunks': 3, 'data': {'chunks': [1, 724, 1448], 'dtype': 'float64', 'chunk_size_mb': 7.998291015625, 'compression': "Blosc(cname='lz4', clevel=5, shuffle=SHUFFLE, blocksize=0)", 'total_array_size': 7.998291015625}}}
# {'other': {'number_coord_chunks': 3, 'data': {'chunks': [1, 724, 1448], 'dtype': 'float64', 'chunk_size_mb': 7.998291015625, 'compression': "Blosc(cname='lz4', clevel=5, shuffle=SHUFFLE, blocksize=0)", 'total_array_size': 7.998291015625}}}
