# %%
import fsspec
import rioxarray
import xarray as xr
import hvplot.xarray as hvplot
import s3fs
import eodc_hub_role
s3fs.core.setup_logging("DEBUG")
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(> .cell-output-ipywidget-background
#     > .lm-Widget
#     > *[data-root-id]),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>

# %%
credentials = eodc_hub_role.fetch_and_set_credentials()
bucket = 'nasa-eodc-data-store'

# %%
#parameters
temporal_resolution = "daily"
model = "GISS-E2-1-G"
variable = "tas"
anon=True

# %%
# Initiate fsspec filesystems for reading and writing
s3_path = f"s3://nex-gddp-cmip6/NEX-GDDP-CMIP6/{model}/historical/r1i1p1*/{variable}/*"
fs_read = fsspec.filesystem("s3", anon=anon, skip_instance_cache=False)
fs_write = fsspec.filesystem("")

# %%
# Retrieve list of available months
files_paths = fs_read.glob(s3_path)
print(f"{len(files_paths)} discovered from {s3_path}")
# Out:
# 2023-07-29 15:48:02,272 - s3fs - DEBUG - _lsdir -- Get directory listing page for nex-gddp-cmip6/NEX-GDDP-CMIP6/GISS-E2-1-G/historical
# 2023-07-29 15:48:02,273 - s3fs - DEBUG - set_session -- Setting up s3fs instance
# 2023-07-29 15:48:02,280 - s3fs - DEBUG - set_session -- RC: caching enabled? False (explicit option is False)
# 2023-07-29 15:48:02,405 - s3fs - DEBUG - _lsdir -- Get directory listing page for nex-gddp-cmip6/NEX-GDDP-CMIP6/GISS-E2-1-G/historical/r1i1p1f2
# 2023-07-29 15:48:02,447 - s3fs - DEBUG - _lsdir -- Get directory listing page for nex-gddp-cmip6/NEX-GDDP-CMIP6/GISS-E2-1-G/historical/r1i1p1f2/hurs
# 2023-07-29 15:48:02,472 - s3fs - DEBUG - _lsdir -- Get directory listing page for nex-gddp-cmip6/NEX-GDDP-CMIP6/GISS-E2-1-G/historical/r1i1p1f2/huss
# 2023-07-29 15:48:02,503 - s3fs - DEBUG - _lsdir -- Get directory listing page for nex-gddp-cmip6/NEX-GDDP-CMIP6/GISS-E2-1-G/historical/r1i1p1f2/pr
# 2023-07-29 15:48:02,526 - s3fs - DEBUG - _lsdir -- Get directory listing page for nex-gddp-cmip6/NEX-GDDP-CMIP6/GISS-E2-1-G/historical/r1i1p1f2/rlds
# 2023-07-29 15:48:02,563 - s3fs - DEBUG - _lsdir -- Get directory listing page for nex-gddp-cmip6/NEX-GDDP-CMIP6/GISS-E2-1-G/historical/r1i1p1f2/rsds
# 2023-07-29 15:48:02,592 - s3fs - DEBUG - _lsdir -- Get directory listing page for nex-gddp-cmip6/NEX-GDDP-CMIP6/GISS-E2-1-G/historical/r1i1p1f2/sfcWind
# 2023-07-29 15:48:02,618 - s3fs - DEBUG - _lsdir -- Get directory listing page for nex-gddp-cmip6/NEX-GDDP-CMIP6/GISS-E2-1-G/historical/r1i1p1f2/tas
# 2023-07-29 15:48:02,645 - s3fs - DEBUG - _lsdir -- Get directory listing page for nex-gddp-cmip6/NEX-GDDP-CMIP6/GISS-E2-1-G/historical/r1i1p1f2/tasmax
# 2023-07-29 15:48:02,668 - s3fs - DEBUG - _lsdir -- Get directory listing page for nex-gddp-cmip6/NEX-GDDP-CMIP6/GISS-E2-1-G/historical/r1i1p1f2/tasmin
# 65 discovered from s3://nex-gddp-cmip6/NEX-GDDP-CMIP6/GISS-E2-1-G/historical/r1i1p1*/tas/*

# %%
fs = s3fs.S3FileSystem(
    key=credentials['AccessKeyId'],
    secret=credentials['SecretAccessKey'],
    token=credentials['SessionToken'], 
    anon=False
)
filepath = f's3://{files_paths[0]}'
f = fs.open(filepath, mode='rb')
ds = xr.open_dataset(f)
ds
# Out:
# 2023-07-29 15:48:05,080 - s3fs - DEBUG - set_session -- Setting up s3fs instance
# 2023-07-29 15:48:05,088 - s3fs - DEBUG - set_session -- RC: caching enabled? False (explicit option is False)
# 2023-07-29 15:48:05,156 - s3fs - DEBUG - _call_s3 -- CALL: head_object - ({},) - {'Bucket': 'nex-gddp-cmip6', 'Key': 'NEX-GDDP-CMIP6/GISS-E2-1-G/historical/r1i1p1f2/tas/tas_day_GISS-E2-1-G_historical_r1i1p1f2_gn_1950.nc'}
# 2023-07-29 15:48:07,074 - s3fs - DEBUG - _fetch_range -- Fetch: nex-gddp-cmip6/NEX-GDDP-CMIP6/GISS-E2-1-G/historical/r1i1p1f2/tas/tas_day_GISS-E2-1-G_historical_r1i1p1f2_gn_1950.nc, 0-5242888
# 2023-07-29 15:48:07,075 - s3fs - DEBUG - _call_s3 -- CALL: get_object - () - {'Bucket': 'nex-gddp-cmip6', 'Key': 'NEX-GDDP-CMIP6/GISS-E2-1-G/historical/r1i1p1f2/tas/tas_day_GISS-E2-1-G_historical_r1i1p1f2_gn_1950.nc', 'Range': 'bytes=0-5242887', 'IfMatch': '"e63fa68f613515cc48c381278d480cc0-30"'}
# 2023-07-29 15:48:07,219 - s3fs - DEBUG - _fetch_range -- Fetch: nex-gddp-cmip6/NEX-GDDP-CMIP6/GISS-E2-1-G/historical/r1i1p1f2/tas/tas_day_GISS-E2-1-G_historical_r1i1p1f2_gn_1950.nc, 242547365-244567317
# 2023-07-29 15:48:07,220 - s3fs - DEBUG - _call_s3 -- CALL: get_object - () - {'Bucket': 'nex-gddp-cmip6', 'Key': 'NEX-GDDP-CMIP6/GISS-E2-1-G/historical/r1i1p1f2/tas/tas_day_GISS-E2-1-G_historical_r1i1p1f2_gn_1950.nc', 'Range': 'bytes=242547365-244567316', 'IfMatch': '"e63fa68f613515cc48c381278d480cc0-30"'}
# 2023-07-29 15:48:07,302 - s3fs - DEBUG - _fetch_range -- Fetch: nex-gddp-cmip6/NEX-GDDP-CMIP6/GISS-E2-1-G/historical/r1i1p1f2/tas/tas_day_GISS-E2-1-G_historical_r1i1p1f2_gn_1950.nc, 242547219-244567317
# 2023-07-29 15:48:07,303 - s3fs - DEBUG - _call_s3 -- CALL: get_object - () - {'Bucket': 'nex-gddp-cmip6', 'Key': 'NEX-GDDP-CMIP6/GISS-E2-1-G/historical/r1i1p1f2/tas/tas_day_GISS-E2-1-G_historical_r1i1p1f2_gn_1950.nc', 'Range': 'bytes=242547219-244567316', 'IfMatch': '"e63fa68f613515cc48c381278d480cc0-30"'}
# 2023-07-29 15:48:07,375 - s3fs - DEBUG - _fetch_range -- Fetch: nex-gddp-cmip6/NEX-GDDP-CMIP6/GISS-E2-1-G/historical/r1i1p1f2/tas/tas_day_GISS-E2-1-G_historical_r1i1p1f2_gn_1950.nc, 711-5244103
# 2023-07-29 15:48:07,376 - s3fs - DEBUG - _call_s3 -- CALL: get_object - () - {'Bucket': 'nex-gddp-cmip6', 'Key': 'NEX-GDDP-CMIP6/GISS-E2-1-G/historical/r1i1p1f2/tas/tas_day_GISS-E2-1-G_historical_r1i1p1f2_gn_1950.nc', 'Range': 'bytes=711-5244102', 'IfMatch': '"e63fa68f613515cc48c381278d480cc0-30"'}
# 2023-07-29 15:48:07,436 - s3fs - DEBUG - _fetch_range -- Fetch: nex-gddp-cmip6/NEX-GDDP-CMIP6/GISS-E2-1-G/historical/r1i1p1f2/tas/tas_day_GISS-E2-1-G_historical_r1i1p1f2_gn_1950.nc, 242546979-244567317
# 2023-07-29 15:48:07,436 - s3fs - DEBUG - _call_s3 -- CALL: get_object - () - {'Bucket': 'nex-gddp-cmip6', 'Key': 'NEX-GDDP-CMIP6/GISS-E2-1-G/historical/r1i1p1f2/tas/tas_day_GISS-E2-1-G_historical_r1i1p1f2_gn_1950.nc', 'Range': 'bytes=242546979-244567316', 'IfMatch': '"e63fa68f613515cc48c381278d480cc0-30"'}
# 2023-07-29 15:48:07,569 - s3fs - DEBUG - _fetch_range -- Fetch: nex-gddp-cmip6/NEX-GDDP-CMIP6/GISS-E2-1-G/historical/r1i1p1f2/tas/tas_day_GISS-E2-1-G_historical_r1i1p1f2_gn_1950.nc, 1220-5244612
# 2023-07-29 15:48:07,570 - s3fs - DEBUG - _call_s3 -- CALL: get_object - () - {'Bucket': 'nex-gddp-cmip6', 'Key': 'NEX-GDDP-CMIP6/GISS-E2-1-G/historical/r1i1p1f2/tas/tas_day_GISS-E2-1-G_historical_r1i1p1f2_gn_1950.nc', 'Range': 'bytes=1220-5244611', 'IfMatch': '"e63fa68f613515cc48c381278d480cc0-30"'}
# 2023-07-29 15:48:07,628 - s3fs - DEBUG - _fetch_range -- Fetch: nex-gddp-cmip6/NEX-GDDP-CMIP6/GISS-E2-1-G/historical/r1i1p1f2/tas/tas_day_GISS-E2-1-G_historical_r1i1p1f2_gn_1950.nc, 242555300-244567317
# 2023-07-29 15:48:07,629 - s3fs - DEBUG - _call_s3 -- CALL: get_object - () - {'Bucket': 'nex-gddp-cmip6', 'Key': 'NEX-GDDP-CMIP6/GISS-E2-1-G/historical/r1i1p1f2/tas/tas_day_GISS-E2-1-G_historical_r1i1p1f2_gn_1950.nc', 'Range': 'bytes=242555300-244567316', 'IfMatch': '"e63fa68f613515cc48c381278d480cc0-30"'}
# 2023-07-29 15:48:07,672 - s3fs - DEBUG - _fetch_range -- Fetch: nex-gddp-cmip6/NEX-GDDP-CMIP6/GISS-E2-1-G/historical/r1i1p1f2/tas/tas_day_GISS-E2-1-G_historical_r1i1p1f2_gn_1950.nc, 618-5243583
# 2023-07-29 15:48:07,672 - s3fs - DEBUG - _call_s3 -- CALL: get_object - () - {'Bucket': 'nex-gddp-cmip6', 'Key': 'NEX-GDDP-CMIP6/GISS-E2-1-G/historical/r1i1p1f2/tas/tas_day_GISS-E2-1-G_historical_r1i1p1f2_gn_1950.nc', 'Range': 'bytes=618-5243582', 'IfMatch': '"e63fa68f613515cc48c381278d480cc0-30"'}
# 2023-07-29 15:48:07,729 - s3fs - DEBUG - _fetch_range -- Fetch: nex-gddp-cmip6/NEX-GDDP-CMIP6/GISS-E2-1-G/historical/r1i1p1f2/tas/tas_day_GISS-E2-1-G_historical_r1i1p1f2_gn_1950.nc, 244562326-244567317
# 2023-07-29 15:48:07,730 - s3fs - DEBUG - _call_s3 -- CALL: get_object - () - {'Bucket': 'nex-gddp-cmip6', 'Key': 'NEX-GDDP-CMIP6/GISS-E2-1-G/historical/r1i1p1f2/tas/tas_day_GISS-E2-1-G_historical_r1i1p1f2_gn_1950.nc', 'Range': 'bytes=244562326-244567316', 'IfMatch': '"e63fa68f613515cc48c381278d480cc0-30"'}
# 2023-07-29 15:48:07,748 - s3fs - DEBUG - _fetch_range -- Fetch: nex-gddp-cmip6/NEX-GDDP-CMIP6/GISS-E2-1-G/historical/r1i1p1f2/tas/tas_day_GISS-E2-1-G_historical_r1i1p1f2_gn_1950.nc, 8310-5251244
# 2023-07-29 15:48:07,749 - s3fs - DEBUG - _call_s3 -- CALL: get_object - () - {'Bucket': 'nex-gddp-cmip6', 'Key': 'NEX-GDDP-CMIP6/GISS-E2-1-G/historical/r1i1p1f2/tas/tas_day_GISS-E2-1-G_historical_r1i1p1f2_gn_1950.nc', 'Range': 'bytes=8310-5251243', 'IfMatch': '"e63fa68f613515cc48c381278d480cc0-30"'}
# 2023-07-29 15:48:07,807 - s3fs - DEBUG - _fetch_range -- Fetch: nex-gddp-cmip6/NEX-GDDP-CMIP6/GISS-E2-1-G/historical/r1i1p1f2/tas/tas_day_GISS-E2-1-G_historical_r1i1p1f2_gn_1950.nc, 4111-5251087
# 2023-07-29 15:48:07,807 - s3fs - DEBUG - _call_s3 -- CALL: get_object - () - {'Bucket': 'nex-gddp-cmip6', 'Key': 'NEX-GDDP-CMIP6/GISS-E2-1-G/historical/r1i1p1f2/tas/tas_day_GISS-E2-1-G_historical_r1i1p1f2_gn_1950.nc', 'Range': 'bytes=4111-5251086', 'IfMatch': '"e63fa68f613515cc48c381278d480cc0-30"'}
# 2023-07-29 15:48:07,874 - s3fs - DEBUG - _fetch_range -- Fetch: nex-gddp-cmip6/NEX-GDDP-CMIP6/GISS-E2-1-G/historical/r1i1p1f2/tas/tas_day_GISS-E2-1-G_historical_r1i1p1f2_gn_1950.nc, 242549571-244567317
# 2023-07-29 15:48:07,874 - s3fs - DEBUG - _call_s3 -- CALL: get_object - () - {'Bucket': 'nex-gddp-cmip6', 'Key': 'NEX-GDDP-CMIP6/GISS-E2-1-G/historical/r1i1p1f2/tas/tas_day_GISS-E2-1-G_historical_r1i1p1f2_gn_1950.nc', 'Range': 'bytes=242549571-244567316', 'IfMatch': '"e63fa68f613515cc48c381278d480cc0-30"'}
# 2023-07-29 15:48:07,912 - s3fs - DEBUG - _fetch_range -- Fetch: nex-gddp-cmip6/NEX-GDDP-CMIP6/GISS-E2-1-G/historical/r1i1p1f2/tas/tas_day_GISS-E2-1-G_historical_r1i1p1f2_gn_1950.nc, 1067-5244001
# 2023-07-29 15:48:07,913 - s3fs - DEBUG - _call_s3 -- CALL: get_object - () - {'Bucket': 'nex-gddp-cmip6', 'Key': 'NEX-GDDP-CMIP6/GISS-E2-1-G/historical/r1i1p1f2/tas/tas_day_GISS-E2-1-G_historical_r1i1p1f2_gn_1950.nc', 'Range': 'bytes=1067-5244000', 'IfMatch': '"e63fa68f613515cc48c381278d480cc0-30"'}
# 2023-07-29 15:48:07,970 - s3fs - DEBUG - _fetch_range -- Fetch: nex-gddp-cmip6/NEX-GDDP-CMIP6/GISS-E2-1-G/historical/r1i1p1f2/tas/tas_day_GISS-E2-1-G_historical_r1i1p1f2_gn_1950.nc, 244566226-244567317
# 2023-07-29 15:48:07,970 - s3fs - DEBUG - _call_s3 -- CALL: get_object - () - {'Bucket': 'nex-gddp-cmip6', 'Key': 'NEX-GDDP-CMIP6/GISS-E2-1-G/historical/r1i1p1f2/tas/tas_day_GISS-E2-1-G_historical_r1i1p1f2_gn_1950.nc', 'Range': 'bytes=244566226-244567316', 'IfMatch': '"e63fa68f613515cc48c381278d480cc0-30"'}
# 2023-07-29 15:48:07,987 - s3fs - DEBUG - _fetch_range -- Fetch: nex-gddp-cmip6/NEX-GDDP-CMIP6/GISS-E2-1-G/historical/r1i1p1f2/tas/tas_day_GISS-E2-1-G_historical_r1i1p1f2_gn_1950.nc, 244564178-244567317
# 2023-07-29 15:48:07,987 - s3fs - DEBUG - _call_s3 -- CALL: get_object - () - {'Bucket': 'nex-gddp-cmip6', 'Key': 'NEX-GDDP-CMIP6/GISS-E2-1-G/historical/r1i1p1f2/tas/tas_day_GISS-E2-1-G_historical_r1i1p1f2_gn_1950.nc', 'Range': 'bytes=244564178-244567316', 'IfMatch': '"e63fa68f613515cc48c381278d480cc0-30"'}
# 2023-07-29 15:48:08,008 - s3fs - DEBUG - _fetch_range -- Fetch: nex-gddp-cmip6/NEX-GDDP-CMIP6/GISS-E2-1-G/historical/r1i1p1f2/tas/tas_day_GISS-E2-1-G_historical_r1i1p1f2_gn_1950.nc, 242550595-244567317
# 2023-07-29 15:48:08,008 - s3fs - DEBUG - _call_s3 -- CALL: get_object - () - {'Bucket': 'nex-gddp-cmip6', 'Key': 'NEX-GDDP-CMIP6/GISS-E2-1-G/historical/r1i1p1f2/tas/tas_day_GISS-E2-1-G_historical_r1i1p1f2_gn_1950.nc', 'Range': 'bytes=242550595-244567316', 'IfMatch': '"e63fa68f613515cc48c381278d480cc0-30"'}
# <xarray.Dataset>
# Dimensions:  (time: 365, lat: 600, lon: 1440)
# Coordinates:
#   * time     (time) object 1950-01-01 12:00:00 ... 1950-12-31 12:00:00
#   * lat      (lat) float64 -59.88 -59.62 -59.38 -59.12 ... 89.38 89.62 89.88
#   * lon      (lon) float64 0.125 0.375 0.625 0.875 ... 359.1 359.4 359.6 359.9
# Data variables:
#     tas      (time, lat, lon) float32 ...
# Attributes: (12/23)
#     downscalingModel:      BCSD
#     activity:              NEX-GDDP-CMIP6
#     contact:               Dr. Rama Nemani: rama.nemani@nasa.gov, Dr. Bridget...
#     Conventions:           CF-1.7
#     creation_date:         2021-10-04T18:41:40.796912+00:00
#     frequency:             day
#     ...                    ...
#     history:               2021-10-04T18:41:40.796912+00:00: install global a...
#     disclaimer:            This data is considered provisional and subject to...
#     external_variables:    areacella
#     cmip6_source_id:       GISS-E2-1-G
#     cmip6_institution_id:  NASA-GISS
#     cmip6_license:         CC-BY-SA 4.0

# %%
chunk_sets = []
# Optimized for analysis
temporal_target_chunks = { 'lat': ds.lat.shape[0], 'lon': ds.lon.shape[0], 'time': 29 }
chunk_sets.append(temporal_target_chunks)

# %%
# Optimized for visualization at a single time step
global_target_chunks = { 'lat': ds.lat.shape[0], 'lon': ds.lon.shape[0], 'time': 1 }
global_target_chunks
chunk_sets.append(global_target_chunks)

# %%
# Optimized for time series
spatial_target_chunks = {'time': 365, 'lat': 262, 'lon': 262}
chunk_sets.append(spatial_target_chunks)

# %%
store = 's3://yuvipanda-test1/cmr/gpm3imergdl.zarr/'
ds = xr.open_dataset(store, engine="zarr", chunks={})
# Out:
# 2023-07-29 15:52:19,509 - s3fs - DEBUG - set_session -- Setting up s3fs instance
# 2023-07-29 15:52:19,517 - s3fs - DEBUG - set_session -- RC: caching enabled? False (explicit option is False)
# 2023-07-29 15:52:19,613 - s3fs - DEBUG - _call_s3 -- CALL: get_object - () - {'Bucket': 'yuvipanda-test1', 'Key': 'cmr/gpm3imergdl.zarr/.zmetadata'}
# 2023-07-29 15:52:19,687 - s3fs - DEBUG - _call_s3 -- CALL: get_object - () - {'Bucket': 'yuvipanda-test1', 'Key': 'cmr/gpm3imergdl.zarr/time/0'}
# 2023-07-29 15:52:19,726 - s3fs - DEBUG - _call_s3 -- CALL: get_object - () - {'Bucket': 'yuvipanda-test1', 'Key': 'cmr/gpm3imergdl.zarr/time/0'}
# 2023-07-29 15:52:19,743 - s3fs - DEBUG - _call_s3 -- CALL: get_object - () - {'Bucket': 'yuvipanda-test1', 'Key': 'cmr/gpm3imergdl.zarr/time_bnds/0.0'}
# 2023-07-29 15:52:19,762 - s3fs - DEBUG - _call_s3 -- CALL: get_object - () - {'Bucket': 'yuvipanda-test1', 'Key': 'cmr/gpm3imergdl.zarr/time_bnds/814.0'}
# 2023-07-29 15:52:19,778 - s3fs - DEBUG - _call_s3 -- CALL: get_object - () - {'Bucket': 'yuvipanda-test1', 'Key': 'cmr/gpm3imergdl.zarr/lat/0'}
# 2023-07-29 15:52:19,818 - s3fs - DEBUG - _call_s3 -- CALL: get_object - () - {'Bucket': 'yuvipanda-test1', 'Key': 'cmr/gpm3imergdl.zarr/lon/0'}
# 2023-07-29 15:52:19,849 - s3fs - DEBUG - _call_s3 -- CALL: get_object - () - {'Bucket': 'yuvipanda-test1', 'Key': 'cmr/gpm3imergdl.zarr/time/0'}

# %%
ds
# Out:
# <xarray.Dataset>
# Dimensions:                    (time: 8149, lon: 3600, lat: 1800, nv: 2)
# Coordinates:
#   * lat                        (lat) float32 -89.95 -89.85 ... 89.85 89.95
#   * lon                        (lon) float32 -179.9 -179.8 ... 179.9 179.9
#   * time                       (time) object 2000-06-01 00:00:00 ... 2022-09-...
# Dimensions without coordinates: nv
# Data variables:
#     HQprecipitation            (time, lon, lat) float32 dask.array<chunksize=(10, 3600, 1800), meta=np.ndarray>
#     HQprecipitation_cnt        (time, lon, lat) int8 dask.array<chunksize=(10, 3600, 1800), meta=np.ndarray>
#     HQprecipitation_cnt_cond   (time, lon, lat) int8 dask.array<chunksize=(10, 3600, 1800), meta=np.ndarray>
#     precipitationCal           (time, lon, lat) float32 dask.array<chunksize=(10, 3600, 1800), meta=np.ndarray>
#     precipitationCal_cnt       (time, lon, lat) int8 dask.array<chunksize=(10, 3600, 1800), meta=np.ndarray>
#     precipitationCal_cnt_cond  (time, lon, lat) int8 dask.array<chunksize=(10, 3600, 1800), meta=np.ndarray>
#     randomError                (time, lon, lat) float32 dask.array<chunksize=(10, 3600, 1800), meta=np.ndarray>
#     randomError_cnt            (time, lon, lat) int8 dask.array<chunksize=(10, 3600, 1800), meta=np.ndarray>
#     time_bnds                  (time, nv) object dask.array<chunksize=(10, 2), meta=np.ndarray>
# Attributes:
#     BeginDate:       2000-06-01
#     BeginTime:       00:00:00.000Z
#     DOI:             10.5067/GPM/IMERGDL/DAY/06
#     EndDate:         2000-06-01
#     EndTime:         23:59:59.999Z
#     FileHeader:      StartGranuleDateTime=2000-06-01T00:00:00.000Z;\nStopGran...
#     InputPointer:    3B-HHR-L.MS.MRG.3IMERG.20000601-S000000-E002959.0000.V06...
#     ProductionTime:  2019-08-07T19:51:27.150Z
#     title:           GPM IMERG Late Precipitation L3 1 day 0.1 degree x 0.1 d...

# %%
for chunk_set in [chunk_sets[1]]:
    dir_path = str(("_").join(map(str, chunk_set.values())))
    store_name = f"{dir_path}/CMIP6_{temporal_resolution}_{model}_{variable}.zarr"
    store = s3fs.S3Map(root=f"{bucket}/{store_name}", s3=fs, check=True)
    ds = xr.open_dataset(store, engine="zarr", chunks={})
    print(ds)
# Out:
# 2023-07-29 15:51:19,854 - s3fs - DEBUG - _call_s3 -- CALL: head_object - ({},) - {'Bucket': 'nasa-eodc-data-store', 'Key': '600_1440_1/CMIP6_daily_GISS-E2-1-G_tas.zarr'}
# 2023-07-29 15:51:19,894 - s3fs - DEBUG - _error_wrapper -- Client error (maybe retryable): An error occurred (404) when calling the HeadObject operation: Not Found
# 2023-07-29 15:51:19,895 - s3fs - DEBUG - _call_s3 -- CALL: list_objects_v2 - ({},) - {'Bucket': 'nasa-eodc-data-store', 'Prefix': '600_1440_1/CMIP6_daily_GISS-E2-1-G_tas.zarr/', 'Delimiter': '/', 'MaxKeys': 1}
# 2023-07-29 15:51:19,982 - s3fs - DEBUG - _call_s3 -- CALL: put_object - () - {'Bucket': 'nasa-eodc-data-store', 'Key': '600_1440_1/CMIP6_daily_GISS-E2-1-G_tas.zarr/a'}
# 2023-07-29 15:51:20,003 - s3fs - DEBUG - _call_s3 -- CALL: delete_objects - ({},) - {'Bucket': 'nasa-eodc-data-store', 'Delete': {'Objects': [{'Key': '600_1440_1/CMIP6_daily_GISS-E2-1-G_tas.zarr/a'}], 'Quiet': True}}
# 2023-07-29 15:51:20,026 - s3fs - DEBUG - _call_s3 -- CALL: head_object - ({},) - {'Bucket': 'nasa-eodc-data-store', 'Key': '600_1440_1/CMIP6_daily_GISS-E2-1-G_tas.zarr'}
# 2023-07-29 15:51:20,052 - s3fs - DEBUG - _error_wrapper -- Client error (maybe retryable): An error occurred (404) when calling the HeadObject operation: Not Found
# 2023-07-29 15:51:20,052 - s3fs - DEBUG - _call_s3 -- CALL: list_objects_v2 - ({},) - {'Bucket': 'nasa-eodc-data-store', 'Prefix': '600_1440_1/CMIP6_daily_GISS-E2-1-G_tas.zarr/', 'Delimiter': '/', 'MaxKeys': 1}
# 2023-07-29 15:51:20,086 - s3fs - DEBUG - _call_s3 -- CALL: put_object - () - {'Bucket': 'nasa-eodc-data-store', 'Key': '600_1440_1/CMIP6_daily_GISS-E2-1-G_tas.zarr
- s3fs - DEBUG - _call_s3 -- CALL: get_object - () - {'Bucket': 'nasa-eodc-data-store', 'Key': '600_1440_1/CMIP6_daily_GISS-E2-1-G_tas.zarr/time/316'}
# 2023-07-29 15:51:20,612 - s3fs - DEBUG - _call_s3 -- CALL: get_object - () - {'Bucket': 'nasa-eodc-data-store', 'Key': '600_1440_1/CMIP6_daily_GISS-E2-1-G_tas.zarr/time/317'}
# 2023-07-29 15:51:20,614 - s3fs - DEBUG - _call_s3 -- CALL: get_object - () - {'Bucket': 'nasa-eodc-data-store', 'Key': '600_1440_1/CMIP6_daily_GISS-E2-1-G_tas.zarr/time/318'}
# 2023-07-29 15:51:20,615 - s3fs - DEBUG - _call_s3 -- CALL: get_object - () - {'Bucket': 'nasa-eodc-data-store', 'Key': '600_1440_1/CMIP6_daily_GISS-E2-1-G_tas.zarr/time/319'}
# 2023-07-29 15:51:20,616 - s3fs - DEBUG - _call_s3 -- CALL: get_object - () - {'Bucket': 'nasa-eodc-data-store', 'Key': '600_1440_1/CMIP6_daily_GISS-E2-1-G_tas.zarr/time/32'}
# 2023-07-29 15:51:20,617 - s3fs - DEBUG - _call_s3 -- CALL: get_object - () - {'Bucket': 'nasa-eodc-data-store', 'Key': '600_1440_1/CMIP6_daily_GISS-E2-1-G_tas.zarr/time/320'}
# 2023-07-29 15:51:20,618 - s3fs - DEBUG - _call_s3 -- CALL: get_object - () - {'Bucket': 'nasa-eodc-data-store', 'Key': '600_1440_1/CMIP6_daily_GISS-E2-1-G_tas.zarr/time/321'}
# 2023-07-29 15:51:20,620 - s3fs - DEBUG - _call_s3 -- CALL: get_object - () - {'Bucket': 'nasa-eodc-data-store', 'Key': '600_1440_1/CMIP6_daily_GISS-E2-1-G_tas.zarr/time/322'}
# 2023-07-29 15:51:20,622 - s3fs - DEBUG - _call_s3 -- CALL: get_object - () - {'Bucket': 'nasa-eodc-data-store', 'Key': '600_1440_1/CMIP6_daily_GISS-E2-1-G_tas.zarr/time/323'}
# 2023-07-29 15:51:20,623 - s3fs - DEBUG - _call_s3 -- CALL: get_object - () - {'Bucket': 'nasa-eodc-data-store', 'Key': '600_1440_1/CMIP6_daily_GISS-E2-1-G_tas.zarr/time/324'}
# 2023-07-29 15:51:20,624 - s3fs - DEBUG - _call_s3 -- CALL: get_object - () - {'Bucket': 'nasa-eodc-data-store', 'Key': '600_1440_1/CMIP6_daily_GISS-E2-1-G_tas.zarr/time/325'}
# 2023-07-29 15:51:20,625 - s3fs - DEBUG - _call_s3 -- CALL: get_object - () - {'Bucket': 'nasa-eodc-data-store', 'Key': '600_1440_1/CMIP6_daily_GISS-E2-1-G_tas.zarr/time/326'}
# 2023-07-29 15:51:20,627 - s3fs - DEBUG - _call_s3 -- CALL: get_object - () - {'Bucket': 'nasa-eodc-data-store', 'Key': '600_1440_1/CMIP6_daily_GISS-E2-1-G_tas.zarr/time/327'}
# 2023-07-29 15:51:20,628 - s3fs - DEBUG - _call_s3 -- CALL: get_object - () - {'Bucket': 'nasa-eodc-data-store', 'Key': '600_1440_1/CMIP6_daily_GISS-E2-1-G_tas.zarr/time/328'}
# 2023-07-29 15:51:20,629 - s3fs - DEBUG - _call_s3 -- CALL: get_object - () - {'Bucket': 'nasa-eodc-data-store', 'Key': '600_1440_1/CMIP6_daily_GISS-E2-1-G_tas.zarr/time/329'}
# 2023-07-29 15:51:20,630 - s3fs - DEBUG - _call_s3 -- CALL: get_object - () - {'Bucket': 'nasa-eodc-data-store', 'Key': '600_1440_1/CMIP6_daily_GISS-E2-1-G_tas.zarr/time/33'}
# ...
# 2023-07-29 15:51:21,127 - s3fs - DEBUG - _call_s3 -- CALL: get_object - () - {'Bucket': 'nasa-eodc-data-store', 'Key': '600_1440_1/CMIP6_daily_GISS-E2-1-G_tas.zarr/time/68'}
# 2023-07-29 15:51:21,129 - s3fs - DEBUG - _call_s3 -- CALL: get_object - () - {'Bucket': 'nasa-eodc-data-store', 'Key': '600_1440_1/CMIP6_daily_GISS-E2-1-G_tas.zarr/time/680'}
# 2023-07-29 15:51:21,130 - s3fs - DEBUG - _call_s3 -- CALL: get_object - () - {'Bucket': 'nasa-eodc-data-store', 'Key': '600_1440_1/CMIP6_daily_GISS-E2-1-G_tas.zarr/time/681'}
# 2023-07-29 15:51:21,132 - s3fs - DEBUG - _call_s3 -- CALL: get_object - () - {'Bucket': 'nasa-eodc-data-store', 'Key': '600_1440_1/CMIP6_daily_GISS-E2-1-G_tas.zarr/time/682'}
# 2023-07-29 15:51:21,133 - s3fs - DEBUG - _call_s3 -- CALL: get_object - () - {'Bucket': 'nasa-eodc-data-store', 'Key': '600_1440_1/CMIP6_daily_GISS-E2-1-G_tas.zarr/time/683'}
# 2023-07-29 15:51:21,134 - s3fs - DEBUG - _call_s3 -- CALL: get_object - () - {'Bucket': 'nasa-eodc-data-store', 'Key': '600_1440_1/CMIP6_daily_GISS-E2-1-G_tas.zarr/time/684'}
# 2023-07-29 15:51:21,135 - s3fs - DEBUG - _call_s3 -- CALL: get_object - () - {'Bucket': 'nasa-eodc-data-store', 'Key': '600_1440_1/CMIP6_daily_GISS-E2-1-G_tas.zarr/time/685'}
# 2023-07-29 15:51:21,136 - s3fs - DEBUG - _call_s3 -- CALL: get_object - () - {'Bucket': 'nasa-eodc-data-store', 'Key': '600_1440_1/CMIP6_daily_GISS-E2-1-G_tas.zarr/time/686'}
# 2023-07-29 15:51:21,138 - s3fs - DEBUG - _call_s3 -- CALL: get_object - () - {'Bucket': 'nasa-eodc-data-store', 'Key': '600_1440_1/CMIP6_daily_GISS-E2-1-G_tas.zarr/time/687'}
# 2023-07-29 15:51:21,139 - s3fs - DEBUG - _call_s3 -- CALL: get_object - () - {'Bucket': 'nasa-eodc-data-store', 'Key': '600_1440_1/CMIP6_daily_GISS-E2-1-G_tas.zarr/time/688'}
# 2023-07-29 15:51:21,140 - s3fs - DEBUG - _call_s3 -- CALL: get_object - () - {'Bucket': 'nasa-eodc-data-store', 'Key': '600_1440_1/CMIP6_daily_GISS-E2-1-G_tas.zarr/time/689'}
# 2023-07-29 15:51:21,141 - s3fs - DEBUG - _call_s3 -- CALL: get_object - () - {'Bucket': 'nasa-eodc-data-store', 'Key': '600_1440_1/CMIP6_daily_GISS-E2-1-G_tas.zarr/time/69'}
# 2023-07-29 15:51:21,143 - s3fs - DEBUG - _call_s3 -- CALL: get_object - () - {'Bucket': 'nasa-eodc-data-store', 'Key': '600_1440_1/CMIP6_daily_GISS-E2-1-G_tas.zarr/time/690'}
# 2023-07-29 15:51:21,144 - s3fs - DEBUG - _call_s3 -- CALL: get_object - () - {'Bucket': 'nasa-eodc-data-store', 'Key': '600_1440_1/CMIP6_daily_GISS-E2-1-G_tas.zarr/time/691'}
# 2023-07-29 15:51:21,145 - s3fs - DEBUG - _call_s3 -- CALL: get_object - () - {'Bucket': 'nasa-eodc-data-store', 'Key': '600_1440_1/CMIP6_daily_GISS-E2-1-G_tas.zarr/time/692'}
# 2023-07-29 15:51:21,146 - s3fs - DEBUG - _call_s3 -- CALL: get_object - () - {'Bucket': 'nasa-eodc-data-store', 'Key': '600_1440_1/CMIP6_daily_GISS-E2-1-G_tas.zarr/time/693'}
# 2023-07-29 15:51:21,148 - s3fs - DEBUG - _call_s3 -- CALL: get_object - () - {'Bucket': 'nasa-eodc-data-store', 'Key': '600_1440_1/CMIP6_daily_GISS-E2-1-G_tas.zarr/time/694'}
# 2023-07-29 15:51:21,149 - s3fs - DEBUG - _call_s3 -- CALL: get_object - () - {'Bucket': 'nasa-eodc-data-store', 'Key': '600_1440_1/CMIP6_daily_GISS-E2-1-G_tas.zarr/time/695'}
# 2023-07-29 15:51:21,150 - s3fs - DEBUG - _call_s3 -- CALL: get_object - () - {'Bucket': 'nasa-eodc-data-store', 'Key': '600_1440_1/CMIP6_daily_GISS-E2-1-G_tas.zarr/time/696'}
# 2023-07-29 15:51:21,152 - s3fs - DEBUG - _call_s3 -- CALL: get_object - () - {'Bucket': 'nasa-eodc-data-store', 'Key': '600_1440_1/CMIP6_daily_GISS-E2-1-G_tas.zarr/time/697'}
# 2023-07-29 15:51:21,153 - s3fs - DEBUG - _call_s3 -- CALL: get_object - () - {'Bucket': 'nasa-eodc-data-store', 'Key': '600_1440_1/CMIP6_daily_GISS-E2-1-G_tas.zarr/time/698'}
# 2023-07-29 15:51:21,154 - s3fs - DEBUG - _call_s3 -- CALL: get_object - () - {'Bucket': 'nasa-eodc-data-store', 'Key': '600_1440_1/CMIP6_daily_GISS-E2-1-G_tas.zarr/time/699'}
# 2023-07-29 15:51:21,155 - s3fs - DEBUG - _call_s3 -- CALL: get_object - () - {'Bucket': 'nasa-eodc-data-store', 'Key': '600_1440_1/CMIP6_daily_GISS-E2-1-G_tas.zarr/time/7'}
# 2023-07-29 15:51:21,156 - s3fs - DEBUG - _call_s3 -- CALL: get_object - () - {'Bucket': 'nasa-eodc-data-store', 'Key': '600_1440_1/CMIP6_daily_GISS-E2-1-G_tas.zarr/time/70'}
# 2023-07-29 15:51:21,158 - s3fs - DEBUG - _call_s3 -- CALL: get_object - () - {'Bucket': 'nasa-eodc-data-store', 'Key': '600_1440_1/CMIP6_daily_GISS-E2-1-G_tas.zarr/time/700'}
# 2023-07-29 15:51:21,159 - s3fs - DEBUG - _call_s3 -- CALL: get_object - () - {'Bucket': 'nasa-eodc-data-store', 'Key': '600_1440_1/CMIP6_daily_GISS-E2-1-G_tas.zarr/time/701'}
# 2023-07-29 15:51:21,161 - s3fs - DEBUG - _call_s3 -- CALL: get_object - () - {'Bucket': 'nasa-eodc-data-store', 'Key': '600_1440_1/CMIP6_daily_GISS-E2-1-G_tas.zarr/time/702'}
# 2023-07-29 15:51:21,162 - s3fs - DEBUG - _call_s3 -- CALL: get_object - () - {'Bucket': 'nasa-eodc-data-store', 'Key': '600_1440_1/CMIP6_daily_GISS-E2-1-G_tas.zarr/time/703'}
# 2023-07-29 15:51:21,163 - s3fs - DEBUG - _call_s3 -- CALL: get_object - () - {'Bucket': 'nasa-eodc-data-store', 'Key': '600_1440_1/CMIP6_daily_GISS-E2-1-G_tas.zarr/time/704'}
# 2023-07-29 15:51:21,165 - s3fs - DEBUG - _call_s3 -- CALL: get_object - () - {'Bucket': 'nasa-eodc-data-store', 'Key': '600_1440_1/CMIP6_daily_GISS-E2-1-G_tas.zarr/time/705'}
# 2023-07-29 15:51:21,166 - s3fs - DEBUG - _call_s3 -- CALL: get_object - () - {'Bucket': 'nasa-eodc-data-store', 'Key': '600_1440_1/CMIP6_daily_GISS-E2-1-G_tas.zarr/time/706'}
# 2023-07-29 15:51:21,167 - s3fs - DEBUG - _call_s3 -- CALL: get_object - () - {'Bucket': 'nasa-eodc-data-store', 'Key': '600_1440_1/CMIP6_daily_GISS-E2-1-G_tas.zarr/time/707'}
# 2023-07-29 15:51:21,169 - s3fs - DEBUG - _call_s3 -- CALL: get_object - () - {'Bucket': 'nasa-eodc-data-store', 'Key': '600_1440_1/CMIP6_daily_GISS-E2-1-G_tas.zarr/time/708'}
# 2023-07-29 15:51:21,170 - s3fs - DEBUG - _call_s3 -- CALL: get_object - () - {'Bucket': 'nasa-eodc-data-store', 'Key': '600_1440_1/CMIP6_daily_GISS-E2-1-G_tas.zarr/time/709'}
# 2023-07-29 15:51:21,172 - s3fs - DEBUG - _call_s3 -- CALL: get_object - () - {'Bucket': 'nasa-eodc-data-store', 'Key': '600_1440_1/CMIP6_daily_GISS-E2-1-G_tas.zarr/time/71'}
# 2023-07-29 15:51:21,173 - s3fs - DEBUG - _call_s3 -- CALL: get_object - () - {'Bucket': 'nasa-eodc-data-store', 'Key': '600_1440_1/CMIP6_daily_GISS-E2-1-G_tas.zarr/time/710'}
# 2023-07-29 15:51:21,174 - s3fs - DEBUG - _call_s3 -- CALL: get_object - () - {'Bucket': 'nasa-eodc-data-store', 'Key': '600_1440_1/CMIP6_daily_GISS-E2-1-G_tas.zarr/time/711'}
# 2023-07-29 15:51:21,175 - s3fs - DEBUG - _call_s3 -- CALL: get_object - () - {'Bucket': 'nasa-eodc-data-store', 'Key': '600_1440_1/CMIP6_daily_GISS-E2-1-G_tas.zarr/time/712'}
# 2023-07-29 15:51:21,177 - s3fs - DEBUG - _call_s3 -- CALL: get_object - () - {'Bucket': 'nasa-eodc-data-store', 'Key': '600_1440_1/CMIP6_daily_GISS-E2-1-G_tas.zarr/time/713'}
# 2023-07-29 15:51:21,178 - s3fs - DEBUG - _call_s3 -- CALL: get_object - () - {'Bucket': 'nasa-eodc-data-store', 'Key': '600_1440_1/CMIP6_daily_GISS-E2-1-G_tas.zarr/time/714'}
# 2023-07-29 15:51:21,179 - s3fs - DEBUG - _call_s3 -- CALL: get_object - () - {'Bucket': 'nasa-eodc-data-store', 'Key': '600_1440_1/CMIP6_daily_GISS-E2-1-G_tas.zarr/time/715'}
# 2023-07-29 15:51:21,181 - s3fs - DEBUG - _call_s3 -- CALL: get_object - () - {'Bucket': 'nasa-eodc-data-store', 'Key': '600_1440_1/CMIP6_daily_GISS-E2-1-G_tas.zarr/time/716'}
# 2023-07-29 15:51:21,182 - s3fs - DEBUG - _call_s3 -- CALL: get_object - () - {'Bucket': 'nasa-eodc-data-store', 'Key': '600_1440_1/CMIP6_daily_GISS-E2-1-G_tas.zarr/time/717'}
# 2023-07-29 15:51:21,183 - s3fs - DEBUG - _call_s3 -- CALL: get_object - () - {'Bucket': 'nasa-eodc-data-store', 'Key': '600_1440_1/CMIP6_daily_GISS-E2-1-G_tas.zarr/time/718'}
# 2023-07-29 15:51:21,184 - s3fs - DEBUG - _call_s3 -- CALL: get_object - () - {'Bucket': 'nasa-eodc-data-store', 'Key': '600_1440_1/CMIP6_daily_GISS-E2-1-G_tas.zarr/time/719'}
# 2023-07-29 15:51:21,186 - s3fs - DEBUG - _call_s3 -- CALL: get_object - () - {'Bucket': 'nasa-eodc-data-store', 'Key': '600_1440_1/CMIP6_daily_GISS-E2-1-G_tas.zarr/time/72'}
# 2023-07-29 15:51:21,187 - s3fs - DEBUG - _call_s3 -- CALL: get_object - () - {'Bucket': 'nasa-eodc-data-store', 'Key': '600_1440_1/CMIP6_daily_GISS-E2-1-G_tas.zarr/time/720'}
# 2023-07-29 15:51:21,188 - s3fs - DEBUG - _call_s3 -- CALL: get_object - () - {'Bucket': 'nasa-eodc-data-store', 'Key': '600_1440_1/CMIP6_daily_GISS-E2-1-G_tas.zarr/time/721'}
# 2023-07-29 15:51:21,189 - s3fs - DEBUG - _call_s3 -- CALL: get_object - () - {'Bucket': 'nasa-eodc-data-store', 'Key': '600_1440_1/CMIP6_daily_GISS-E2-1-G_tas.zarr/time/722'}
# 2023-07-29 15:51:21,190 - s3fs - DEBUG - _call_s3 -- CALL: get_object - () - {'Bucket': 'nasa-eodc-data-store', 'Key': '600_1440_1/CMIP6_daily_GISS-E2-1-G_tas.zarr/time/723'}
# 2023-07-29 15:51:21,191 - s3fs - DEBUG - _call_s3 -- CALL: get_object - () - {'Bucket': 'nasa-eodc-data-store', 'Key': '600_1440_1/CMIP6_daily_GISS-E2-1-G_tas.zarr/time/724'}
# 2023-07-29 15:51:21,193 - s3fs - DEBUG - _call_s3 -- CALL: get_object - () - {'Bucket': 'nasa-eodc-data-store', 'Key': '600_1440_1/CMIP6_daily_GISS-E2-1-G_tas.zarr/time/725'}
# 2023-07-29 15:51:21,194 - s3fs - DEBUG - _call_s3 -- CALL: get_object - () - {'Bucket': 'nasa-eodc-data-store', 'Key': '600_1440_1/CMIP6_daily_GISS-E2-1-G_tas.zarr/time/726'}
# 2023-07-29 15:51:21,195 - s3fs - DEBUG - _call_s3 -- CALL: get_object - () - {'Bucket': 'nasa-eodc-data-store', 'Key': '600_1440_1/CMIP6_daily_GISS-E2-1-G_tas.zarr/time/727'}
# 2023-07-29 15:51:21,197 - s3fs - DEBUG - _call_s3 -- CALL: get_object - () - {'Bucket': 'nasa-eodc-data-store', 'Key': '600_1440_1/CMIP6_daily_GISS-E2-1-G_tas.zarr/time/728'}
# 2023-07-29 15:51:21,198 - s3fs - DEBUG - _call_s3 -- CALL: get_object - () - {'Bucket': 'nasa-eodc-data-store', 'Key': '600_1440_1/CMIP6_daily_GISS-E2-1-G_tas.zarr/time/729'}
# 2023-07-29 15:51:21,200 - s3fs - DEBUG - _call_s3 -- CALL: get_object - () - {'Bucket': 'nasa-eodc-data-store', 'Key': '600_1440_1/CMIP6_daily_GISS-E2-1-G_tas.zarr/time/73'}
# 2023-07-29 15:51:21,201 - s3fs - DEBUG - _call_s3 -- CALL: get_object - () - {'Bucket': 'nasa-eodc-data-store', 'Key': '600_1440_1/CMIP6_daily_GISS-E2-1-G_tas.zarr/time/74'}
# 2023-07-29 15:51:21,202 - s3fs - DEBUG - _call_s3 -- CALL: get_object - () - {'Bucket': 'nasa-eodc-data-store', 'Key': '600_1440_1/CMIP6_daily_GISS-E2-1-G_tas.zarr/time/75'}
# 2023-07-29 15:51:21,203 - s3fs - DEBUG - _call_s3 -- CALL: get_object - () - {'Bucket': 'nasa-eodc-data-store', 'Key': '600_1440_1/CMIP6_daily_GISS-E2-1-G_tas.zarr/time/76'}
# 2023-07-29 15:51:21,205 - s3fs - DEBUG - _call_s3 -- CALL: get_object - () - {'Bucket': 'nasa-eodc-data-store', 'Key': '600_1440_1/CMIP6_daily_GISS-E2-1-G_tas.zarr/time/77'}
# 2023-07-29 15:51:21,206 - s3fs - DEBUG - _call_s3 -- CALL: get_object - () - {'Bucket': 'nasa-eodc-data-store', 'Key': '600_1440_1/CMIP6_daily_GISS-E2-1-G_tas.zarr/time/78'}
# 2023-07-29 15:51:21,207 - s3fs - DEBUG - _call_s3 -- CALL: get_object - () - {'Bucket': 'nasa-eodc-data-store', 'Key': '600_1440_1/CMIP6_daily_GISS-E2-1-G_tas.zarr/time/79'}
# 2023-07-29 15:51:21,208 - s3fs - DEBUG - _call_s3 -- CALL: get_object - () - {'Bucket': 'nasa-eodc-data-store', 'Key': '600_1440_1/CMIP6_daily_GISS-E2-1-G_tas.zarr/time/8'}
# 2023-07-29 15:51:21,210 - s3fs - DEBUG - _call_s3 -- CALL: get_object - () - {'Bucket': 'nasa-eodc-data-store', 'Key': '600_1440_1/CMIP6_daily_GISS-E2-1-G_tas.zarr/time/80'}
# 2023-07-29 15:51:21,211 - s3fs - DEBUG - _call_s3 -- CALL: get_object - () - {'Bucket': 'nasa-eodc-data-store', 'Key': '600_1440_1/CMIP6_daily_GISS-E2-1-G_tas.zarr/time/81'}
# 2023-07-29 15:51:21,212 - s3fs - DEBUG - _call_s3 -- CALL: get_object - () - {'Bucket': 'nasa-eodc-data-store', 'Key': '600_1440_1/CMIP6_daily_GISS-E2-1-G_tas.zarr/time/82'}
# 2023-07-29 15:51:21,213 - s3fs - DEBUG - _call_s3 -- CALL: get_object - () - {'Bucket': 'nasa-eodc-data-store', 'Key': '600_1440_1/CMIP6_daily_GISS-E2-1-G_tas.zarr/time/83'}
# 2023-07-29 15:51:21,214 - s3fs - DEBUG - _call_s3 -- CALL: get_object - () - {'Bucket': 'nasa-eodc-data-store', 'Key': '600_1440_1/CMIP6_daily_GISS-E2-1-G_tas.zarr/time/84'}
# 2023-07-29 15:51:21,216 - s3fs - DEBUG - _call_s3 -- CALL: get_object - () - {'Bucket': 'nasa-eodc-data-store', 'Key': '600_1440_1/CMIP6_daily_GISS-E2-1-G_tas.zarr/time/85'}
# 2023-07-29 15:51:21,217 - s3fs - DEBUG - _call_s3 -- CALL: get_object - () - {'Bucket': 'nasa-eodc-data-store', 'Key': '600_1440_1/CMIP6_daily_GISS-E2-1-G_tas.zarr/time/86'}
# 2023-07-29 15:51:21,219 - s3fs - DEBUG - _call_s3 -- CALL: get_object - () - {'Bucket': 'nasa-eodc-data-store', 'Key': '600_1440_1/CMIP6_daily_GISS-E2-1-G_tas.zarr/time/87'}
# 2023-07-29 15:51:21,220 - s3fs - DEBUG - _call_s3 -- CALL: get_object - () - {'Bucket': 'nasa-eodc-data-store', 'Key': '600_1440_1/CMIP6_daily_GISS-E2-1-G_tas.zarr/time/88'}
# 2023-07-29 15:51:21,221 - s3fs - DEBUG - _call_s3 -- CALL: get_object - () - {'Bucket': 'nasa-eodc-data-store', 'Key': '600_1440_1/CMIP6_daily_GISS-E2-1-G_tas.zarr/time/89'}
# 2023-07-29 15:51:21,222 - s3fs - DEBUG - _call_s3 -- CALL: get_object - () - {'Bucket': 'nasa-eodc-data-store', 'Key': '600_1440_1/CMIP6_daily_GISS-E2-1-G_tas.zarr/time/9'}
# 2023-07-29 15:51:21,224 - s3fs - DEBUG - _call_s3 -- CALL: get_object - () - {'Bucket': 'nasa-eodc-data-store', 'Key': '600_1440_1/CMIP6_daily_GISS-E2-1-G_tas.zarr/time/90'}
# 2023-07-29 15:51:21,225 - s3fs - DEBUG - _call_s3 -- CALL: get_object - () - {'Bucket': 'nasa-eodc-data-store', 'Key': '600_1440_1/CMIP6_daily_GISS-E2-1-G_tas.zarr/time/91'}
# 2023-07-29 15:51:21,226 - s3fs - DEBUG - _call_s3 -- CALL: get_object - () - {'Bucket': 'nasa-eodc-data-store', 'Key': '600_1440_1/CMIP6_daily_GISS-E2-1-G_tas.zarr/time/92'}
# 2023-07-29 15:51:21,228 - s3fs - DEBUG - _call_s3 -- CALL: get_object - () - {'Bucket': 'nasa-eodc-data-store', 'Key': '600_1440_1/CMIP6_daily_GISS-E2-1-G_tas.zarr/time/93'}
# 2023-07-29 15:51:21,229 - s3fs - DEBUG - _call_s3 -- CALL: get_object - () - {'Bucket': 'nasa-eodc-data-store', 'Key': '600_1440_1/CMIP6_daily_GISS-E2-1-G_tas.zarr/time/94'}
# 2023-07-29 15:51:21,230 - s3fs - DEBUG - _call_s3 -- CALL: get_object - () - {'Bucket': 'nasa-eodc-data-store', 'Key': '600_1440_1/CMIP6_daily_GISS-E2-1-G_tas.zarr/time/95'}
# 2023-07-29 15:51:21,231 - s3fs - DEBUG - _call_s3 -- CALL: get_object - () - {'Bucket': 'nasa-eodc-data-store', 'Key': '600_1440_1/CMIP6_daily_GISS-E2-1-G_tas.zarr/time/96'}
# 2023-07-29 15:51:21,233 - s3fs - DEBUG - _call_s3 -- CALL: get_object - () - {'Bucket': 'nasa-eodc-data-store', 'Key': '600_1440_1/CMIP6_daily_GISS-E2-1-G_tas.zarr/time/97'}
# 2023-07-29 15:51:21,234 - s3fs - DEBUG - _call_s3 -- CALL: get_object - () - {'Bucket': 'nasa-eodc-data-store', 'Key': '600_1440_1/CMIP6_daily_GISS-E2-1-G_tas.zarr/time/98'}
# 2023-07-29 15:51:21,235 - s3fs - DEBUG - _call_s3 -- CALL: get_object - () - {'Bucket': 'nasa-eodc-data-store', 'Key': '600_1440_1/CMIP6_daily_GISS-E2-1-G_tas.zarr/time/99'}
# <xarray.Dataset>
# Dimensions:  (lat: 600, lon: 1440, time: 730)
# Coordinates:
#   * lat      (lat) float64 -59.88 -59.62 -59.38 -59.12 ... 89.38 89.62 89.88
#   * lon      (lon) float64 0.125 0.375 0.625 0.875 ... 359.1 359.4 359.6 359.9
#   * time     (time) object 1950-01-01 12:00:00 ... 1950-12-31 12:00:00
# Data variables:
#     tas      (time, lat, lon) float32 dask.array<chunksize=(1, 600, 1440), meta=np.ndarray>
# Attributes: (12/23)
#     Conventions:           CF-1.7
#     activity:              NEX-GDDP-CMIP6
#     cmip6_institution_id:  NASA-GISS
#     cmip6_license:         CC-BY-SA 4.0
#     cmip6_source_id:       GISS-E2-1-G
#     contact:               Dr. Rama Nemani: rama.nemani@nasa.gov, Dr. Bridget...
#     ...                    ...
#     scenario:              historical
#     source:                BCSD
#     title:                 GISS-E2-1-G, r1i1p1f2, historical, global downscal...
#     tracking_id:           25d6baa3-0404-4eba-a3f1-afddbf69d4cc
#     variant_label:         r1i1p1f2
#     version:               1.0

# %%
ds
