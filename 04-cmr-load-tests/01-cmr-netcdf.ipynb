# %%
import sys
from urllib.parse import urlencode

import hvplot.pandas  # noqa
import pandas as pd

sys.path.append("..")
import subprocess
from datetime import datetime

import helpers.dataframe as dataframe_helpers
import helpers.eodc_hub_role as eodc_hub_role
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='p1002'>
#   <div id="f60f85dc-b5a7-4f79-8d47-c8f56920face" data-root-id="p1002" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"b1a0f418-2006-4c8f-9fc5-bff9d9543062":{"version":"3.4.1","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"p1002"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"p1003","attributes":{"plot_id":"p1002","comm_id":"ad09b91a76fa4770b829ff78921e939d","client_comm_id":"e8a19700d4d24729a02f089c42d8688a"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"gap","kind":"Any","default":""},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"TemplateEditor1","properties":[{"name":"layout","kind":"Any","default":[]}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"copy_to_clipboard1","properties":[{"name":"fill","kind":"A ...
#   var render_items = [{"docid":"b1a0f418-2006-4c8f-9fc5-bff9d9543062","roots":{"p1002":"f60f85dc-b5a7-4f79-8d47-c8f56920face"},"root_ids":["p1002"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   async function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     await Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && id_el.children[0].hasAttribute('data-root-id')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	  for (const child of root_el.children) {
#             // Ensure JupyterLab does not capture keyboard shortcuts
#             // see: https://jupyterlab.readthedocs.io/en/4.1.x/extension/notebook.html#keyboard-interaction-model
# 	    child.setAttribute('data-lm-suppress-shortcuts', 'true')
# 	  }
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>

# %% [markdown]
# ## Specify CMRBackend test results file

# %%
uri = "s3://nasa-eodc-data-store/test-results/20240814010546_CMRTileTest_C2723754850-GES_DISC.json"
test_id = uri.split("/")[-1].split(".")[0]
urls_output_file = f"urls/{test_id}.csv"
kwargs = {"rescale": "0,455", "colormap_name": "coolwarm"}

# %% [markdown]
# ## Generate utility functions for defining API queries corresponding to the CMRBackend tests

# %%
def gen_datetime_query(temporal):
    ###
    return pd.to_datetime(temporal[0]).isoformat("T") + "Z"


def gen_query(
    concept_id,
    variable,
    temporal,
    tile,
    *,
    tms: str = "WebMercatorQuad",
    backend: str = "xarray",
    scale: int = 1,
    return_mask: str = "true",
    **kwargs,
):
    temporal = gen_datetime_query(temporal)
    x, y, z = tile
    query = urlencode(
        {
            "concept_id": concept_id,
            "variable": variable,
            "datetime": temporal,
            "backend": backend,
            "scale": scale,
            "return_mask": return_mask,
            **kwargs,
        }
    )
    return f"/tiles/{tms}/{z}/{x}/{y}?{query}"


def generate_locust_urls(uri):
    credentials = eodc_hub_role.fetch_and_set_credentials()
    df = dataframe_helpers.load_all_into_dataframe(credentials, [uri], use_boto3=False)
    df = dataframe_helpers.expand_timings(df).reset_index()
    df["temporal"] = df.apply(lambda x: x["cmr_query"]["temporal"], axis=1)
    df["query"] = df.apply(
        lambda x: gen_query(
            x["dataset_id"], x["variable"], x["temporal"], x["tile"], **kwargs
        ),
        axis=1,
    )
    df["query"].to_csv(urls_output_file, index=False, header=False)
    return df

# %% [markdown]
# ## Use locust to time tile generation

# %%
df = generate_locust_urls(uri)
current_datetime = datetime.now().strftime("%Y-%m-%d_%H-%M-%S")
results_output = f"results/{test_id}-{current_datetime}"
command = f"locust -f locust_titiler_cmr.py --headless --users 1 --iterations 1 --csv {results_output} --urls-file {urls_output_file} --csv-full-history --host https://dev-titiler-cmr.delta-backend.com"
subprocess.call(command, shell=True)
# Out:
# [2024-08-14 01:06:54,484] jupyter-maxrjones--tile-2dbenchmarking/INFO/locust.main: No run time limit set, use CTRL+C to interrupt
# [2024-08-14 01:06:54,484] jupyter-maxrjones--tile-2dbenchmarking/INFO/locust.main: Starting Locust 2.30.0
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated                                                                         0     0(0.00%) |      0       0       0      0 |    0.00        0.00
#
# [2024-08-14 01:06:54,505] jupyter-maxrjones--tile-2dbenchmarking/INFO/locust.runners: Ramping to 1 users at a rate of 1.00 per second
# [2024-08-14 01:06:54,505] jupyter-maxrjones--tile-2dbenchmarking/INFO/locust.runners: All users spawned: {"TitilerCmrUser": 1} (1 total users)
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated                                                                         0     0(0.00%) |      0       0       0      0 |    0.00        0.00
#
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated                                                                         0     0(0.00%) |      0       0       0      0 |    0.00        0.00
#
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated                                                                         0     0(0.00%) |      0       0       0      0 |    0.00        0.00
#
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated                                                                         0     0(0.00%) |      0       0       0      0 |    0.00        0.00
#
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated                                                                         0     0(0.00%) |      0       0       0      0 |    0.00        0.00
#
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# GET      /tiles/WebMercatorQuad/0/0/0?concept_id=C2723754850-GES_DISC&variable=precipitation&datetime=2024-02-11T00%3A00%3A00Z&backend=xarray&scale=1&return_mask=true&rescale=0%2C455&colormap_name=coolwarm       1     0(0.00%) |  11196   11196   11196  11196 |    0.00        0.00
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated                                                                         1     0(0.00%) |  11196   11196   11196  11196 |    0.00        0.00
#
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# GET      /tiles/WebMercatorQuad/0/0/0?concept_id=C2723754850-GES_DISC&variable=precipitation&datetime=2024-02-11T00%3A00%3A00Z&backend=xarray&scale=1&return_mask=true&rescale=0%2C455&colormap_name=coolwarm       1     0(0.00%) |  11196   11196   11196  11196 |    0.00        0.00
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated                                                                         1     0(0.00%) |  11196   11196   11196  11196 |    0.00        0.00
#
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# GET      /tiles/WebMercatorQuad/0/0/0?concept_id=C2723754850-GES_DISC&variable=precipitation&datetime=2024-02-11T00%3A00%3A00Z&backend=xarray&scale=1&return_mask=true&rescale=0%2C455&colormap_name=coolwarm       2     0(0.00%) |   7170    3144   11196   3144 |    0.10        0.00
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated                                                                         2     0(0.00%) |   7170    3144   11196   3144 |    0.10        0.00
#
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# GET      /tiles/WebMercatorQuad/0/0/0?concept_id=C2723754850-GES_DISC&variable=precipitation&datetime=2024-02-11T00%3A00%3A00Z&backend=xarray&scale=1&return_mask=true&rescale=0%2C455&colormap_name=coolwarm       3     0(0.00%) |   5810    3088   11196   3100 |    0.20        0.00
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated                                                                         3     0(0.00%) |   5810    3088   11196   3100 |    0.20        0.00
#
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# GET      /tiles/WebMercatorQuad/0/0/0?concept_id=C2723754850-GES_DISC&variable=precipitation&datetime=2024-02-11T00%3A00%3A00Z&backend=xarray&scale=1&return_mask=true&rescale=0%2C455&colormap_name=coolwarm       3     0(0.00%) |   5810    3088   11196   3100 |    0.20        0.00
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated                                                                         3     0(0.00%) |   5810    3088   11196   3100 |    0.20        0.00
#
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# GET      /tiles/WebMercatorQuad/0/0/0?concept_id=C2723754850-GES_DISC&variable=precipitation&datetime=2024-02-11T00%3A00%3A00Z&backend=xarray&scale=1&return_mask=true&rescale=0%2C455&colormap_name=coolwarm       4     0(0.00%) |   5087    2921   11196   3100 |    0.30        0.00
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated                                                                         4     0(0.00%) |   5087    2921   11196   3100 |    0.30        0.00
#
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# GET      /tiles/WebMercatorQuad/0/0/0?concept_id=C2723754850-GES_DISC&variable=precipitation&datetime=2024-02-11T00%3A00%3A00Z&backend=xarray&scale=1&return_mask=true&rescale=0%2C455&colormap_name=coolwarm       5     0(0.00%) |   4696    2921   11196   3100 |    0.40        0.00
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated                                                                         5     0(0.00%) |   4696    2921   11196   3100 |    0.40        0.00
#
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# GET      /tiles/WebMercatorQuad/0/0/0?concept_id=C2723754850-GES_DISC&variable=precipitation&datetime=2024-02-11T00%3A00%3A00Z&backend=xarray&scale=1&return_mask=true&rescale=0%2C455&colormap_name=coolwarm       5     0(0.00%) |   4696    2921   11196   3100 |    0.40        0.00
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated                                                                         5     0(0.00%) |   4696    2921   11196   3100 |    0.40        0.00
#
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# GET      /tiles/WebMercatorQuad/0/0/0?concept_id=C2723754850-GES_DISC&variable=precipitation&datetime=2024-02-11T00%3A00%3A00Z&backend=xarray&scale=1&return_mask=true&rescale=0%2C455&colormap_name=coolwarm       6     0(0.00%) |   4415    2921   11196   3100 |    0.30        0.00
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated                                                                         6     0(0.00%) |   4415    2921   11196   3100 |    0.30        0.00
#
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# GET      /tiles/WebMercatorQuad/0/0/0?concept_id=C2723754850-GES_DISC&variable=precipitation&datetime=2024-02-11T00%3A00%3A00Z&backend=xarray&scale=1&return_mask=true&rescale=0%2C455&colormap_name=coolwarm       7     0(0.00%) |   4196    2878   11196   3100 |    0.30        0.00
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated                                                                         7     0(0.00%) |   4196    2878   11196   3100 |    0.30        0.00
#
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# GET      /tiles/WebMercatorQuad/0/0/0?concept_id=C2723754850-GES_DISC&variable=precipitation&datetime=2024-02-11T00%3A00%3A00Z&backend=xarray&scale=1&return_mask=true&rescale=0%2C455&colormap_name=coolwarm       7     0(0.00%) |   4196    2878   11196   3100 |    0.30        0.00
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated                                                                         7     0(0.00%) |   4196    2878   11196   3100 |    0.30        0.00
#
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# GET      /tiles/WebMercatorQuad/0/0/0?concept_id=C2723754850-GES_DISC&variable=precipitation&datetime=2024-02-11T00%3A00%3A00Z&backend=xarray&scale=1&return_mask=true&rescale=0%2C455&colormap_name=coolwarm       8     0(0.00%) |   4020    2794   11196   3000 |    0.40        0.00
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated                                                                         8     0(0.00%) |   4020    2794   11196   3000 |    0.40        0.00
#
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# GET      /tiles/WebMercatorQuad/0/0/0?concept_id=C2723754850-GES_DISC&variable=precipitation&datetime=2024-02-11T00%3A00%3A00Z&backend=xarray&scale=1&return_mask=true&rescale=0%2C455&colormap_name=coolwarm       9     0(0.00%) |   3898    2794   11196   3000 |    0.40        0.00
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated                                                                         9     0(0.00%) |   3898    2794   11196   3000 |    0.40        0.00
#
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# GET      /tiles/WebMercatorQuad/0/0/0?concept_id=C2723754850-GES_DISC&variable=precipitation&datetime=2024-02-11T00%3A00%3A00Z&backend=xarray&scale=1&return_mask=true&rescale=0%2C455&colormap_name=coolwarm      10     0(0.00%) |   3775    2670   11196   2900 |    0.40        0.00
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated                                                                        10     0(0.00%) |   3775    2670   11196   2900 |    0.40        0.00
#
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# GET      /tiles/WebMercatorQuad/0/0/0?concept_id=C2723754850-GES_DISC&variable=precipitation&datetime=2024-02-11T00%3A00%3A00Z&backend=xarray&scale=1&return_mask=true&rescale=0%2C455&colormap_name=coolwarm      10     0(0.00%) |   3775    2670   11196   2900 |    0.40        0.00
# GET      /tiles/WebMercatorQuad/1/1/0?concept_id=C2723754850-GES_DISC&variable=precipitation&datetime=2024-02-11T00%3A00%3A00Z&backend=xarray&scale=1&return_mask=true&rescale=0%2C455&colormap_name=coolwarm       1     0(0.00%) |   1432    1432    1432   1432 |    0.00        0.00
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated                                                                        11     0(0.00%) |   3562    1432   11196   2900 |    0.40        0.00
#
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# GET      /tiles/WebMercatorQuad/0/0/0?concept_id=C2723754850-GES_DISC&variable=precipitation&datetime=2024-02-11T00%3A00%3A00Z&backend=xarray&scale=1&return_mask=true&rescale=0%2C455&colormap_name=coolwarm      10     0(0.00%) |   3775    2670   11196   2900 |    0.30        0.00
# GET      /tiles/WebMercatorQuad/1/0/0?concept_id=C2723754850-GES_DISC&variable=precipitation&datetime=2024-02-11T00%3A00%3A00Z&backend=xarray&scale=1&return_mask=true&rescale=0%2C455&colormap_name=coolwarm       1     0(0.00%) |   1745    1745    1745   1745 |    0.00        0.00
# GET      /tiles/WebMercatorQuad/1/1/0?concept_id=C2723754850-GES_DISC&variable=precipitation&datetime=2024-02-11T00%3A00%3A00Z&backend=xarray&scale=1&return_mask=true&rescale=0%2C455&colormap_name=coolwarm       2     0(0.00%) |   1161     889    1432    890 |    0.10        0.00
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated                                                                        13     0(0.00%) |   3217     889   11196   2900 |    0.40        0.00
#
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# GET      /tiles/WebMercatorQuad/0/0/0?concept_id=C2723754850-GES_DISC&variable=precipitation&datetime=2024-02-11T00%3A00%3A00Z&backend=xarray&scale=1&return_mask=true&rescale=0%2C455&colormap_name=coolwarm      10     0(0.00%) |   3775    2670   11196   2900 |    0.30        0.00
# GET      /tiles/WebMercatorQuad/1/0/0?concept_id=C2723754850-GES_DISC&variable=precipitation&datetime=2024-02-11T00%3A00%3A00Z&backend=xarray&scale=1&return_mask=true&rescale=0%2C455&colormap_name=coolwarm       1     0(0.00%) |   1745    1745    1745   1745 |    0.00        0.00
# GET      /tiles/WebMercatorQuad/1/1/0?concept_id=C2723754850-GES_DISC&variable=precipitation&datetime=2024-02-11T00%3A00%3A00Z&backend=xarray&scale=1&return_mask=true&rescale=0%2C455&colormap_name=coolwarm       2     0(0.00%) |   1161     889    1432    890 |    0.10        0.00
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated                                                                        13     0(0.00%) |   3217     889   11196   2900 |    0.40        0.00
#
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# GET      /tiles/WebMercatorQuad/0/0/0?concept_id=C2723754850-GES_DISC&variable=precipitation&datetime=2024-02-11T00%3A00%3A00Z&backend=xarray&scale=1&return_mask=true&rescale=0%2C455&colormap_name=coolwarm      10     0(0.00%) |   3775    2670   11196   2900 |    0.30        0.00
# GET      /tiles/WebMercatorQuad/1/0/0?concept_id=C2723754850-GES_DISC&variable=precipitation&datetime=2024-02-11T00%3A00%3A00Z&backend=xarray&scale=1&return_mask=true&rescale=0%2C455&colormap_name=coolwarm       1     0(0.00%) |   1745    1745    1745   1745 |    0.10        0.00
# GET      /tiles/WebMercatorQuad/1/1/0?concept_id=C2723754850-GES_DISC&variable=precipitation&datetime=2024-02-11T00%3A00%3A00Z&backend=xarray&scale=1&return_mask=true&rescale=0%2C455&colormap_name=coolwarm       2     0(0.00%) |   1161     889    1432    890 |    0.10        0.00
# GET      /tiles/WebMercatorQuad/1/1/1?concept_id=C2723754850-GES_DISC&variable=precipitation&datetime=2024-02-11T00%3A00%3A00Z&backend=xarray&scale=1&return_mask=true&rescale=0%2C455&colormap_name=coolwarm       1     0(0.00%) |   2526    2526    2526   2526 |    0.00        0.00
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated                                                                        14     0(0.00%) |   3168     889   11196   2900 |    0.50        0.00
#
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# GET      /tiles/WebMercatorQuad/0/0/0?concept_id=C2723754850-GES_DISC&variable=precipitation&datetime=2024-02-11T00%3A00%3A00Z&backend=xarray&scale=1&return_mask=true&rescale=0%2C455&colormap_name=coolwarm      10     0(0.00%) |   3775    2670   11196   2900 |    0.20        0.00
# GET      /tiles/WebMercatorQuad/1/0/0?concept_id=C2723754850-GES_DISC&variable=precipitation&datetime=2024-02-11T00%3A00%3A00Z&backend=xarray&scale=1&return_mask=true&rescale=0%2C455&colormap_name=coolwarm       1     0(0.00%) |   1745    1745    1745   1745 |    0.10        0.00
# GET      /tiles/WebMercatorQuad/1/0/1?concept_id=C2723754850-GES_DISC&variable=precipitation&datetime=2024-02-11T00%3A00%3A00Z&backend=xarray&scale=1&return_mask=true&rescale=0%2C455&colormap_name=coolwarm       2     0(0.00%) |   1498     985    2011    990 |    0.00        0.00
# GET      /tiles/WebMercatorQuad/1/1/0?concept_id=C2723754850-GES_DISC&variable=precipitation&datetime=2024-02-11T00%3A00%3A00Z&backend=xarray&scale=1&return_mask=true&rescale=0%2C455&colormap_name=coolwarm       2     0(0.00%) |   1161     889    1432    890 |    0.20        0.00
# GET      /tiles/WebMercatorQuad/1/1/1?concept_id=C2723754850-GES_DISC&variable=precipitation&datetime=2024-02-11T00%3A00%3A00Z&backend=xarray&scale=1&return_mask=true&rescale=0%2C455&colormap_name=coolwarm       1     0(0.00%) |   2526    2526    2526   2526 |    0.10        0.00
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated                                                                        16     0(0.00%) |   2959     889   11196   2800 |    0.60        0.00
#
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# GET      /tiles/WebMercatorQuad/0/0/0?concept_id=C2723754850-GES_DISC&variable=precipitation&datetime=2024-02-11T00%3A00%3A00Z&backend=xarray&scale=1&return_mask=true&rescale=0%2C455&colormap_name=coolwarm      10     0(0.00%) |   3775    2670   11196   2900 |    0.10        0.00
# GET      /tiles/WebMercatorQuad/1/0/0?concept_id=C2723754850-GES_DISC&variable=precipitation&datetime=2024-02-11T00%3A00%3A00Z&backend=xarray&scale=1&return_mask=true&rescale=0%2C455&colormap_name=coolwarm       2     0(0.00%) |   1314     883    1745    883 |    0.10        0.00
# GET      /tiles/WebMercatorQuad/1/0/1?concept_id=C2723754850-GES_DISC&variable=precipitation&datetime=2024-02-11T00%3A00%3A00Z&backend=xarray&scale=1&return_mask=true&rescale=0%2C455&colormap_name=coolwarm       2     0(0.00%) |   1498     985    2011    990 |    0.10        0.00
# GET      /tiles/WebMercatorQuad/1/1/0?concept_id=C2723754850-GES_DISC&variable=precipitation&datetime=2024-02-11T00%3A00%3A00Z&backend=xarray&scale=1&return_mask=true&rescale=0%2C455&colormap_name=coolwarm       3     0(0.00%) |   1064     870    1432    890 |    0.20        0.00
# GET      /tiles/WebMercatorQuad/1/1/1?concept_id=C2723754850-GES_DISC&variable=precipitation&datetime=2024-02-11T00%3A00%3A00Z&backend=xarray&scale=1&return_mask=true&rescale=0%2C455&colormap_name=coolwarm       1     0(0.00%) |   2526    2526    2526   2526 |    0.10        0.00
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated                                                                        18     0(0.00%) |   2727     870   11196   2700 |    0.60        0.00
#
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# GET      /tiles/WebMercatorQuad/0/0/0?concept_id=C2723754850-GES_DISC&variable=precipitation&datetime=2024-02-11T00%3A00%3A00Z&backend=xarray&scale=1&return_mask=true&rescale=0%2C455&colormap_name=coolwarm      10     0(0.00%) |   3775    2670   11196   2900 |    0.00        0.00
# GET      /tiles/WebMercatorQuad/1/0/0?concept_id=C2723754850-GES_DISC&variable=precipitation&datetime=2024-02-11T00%3A00%3A00Z&backend=xarray&scale=1&return_mask=true&rescale=0%2C455&colormap_name=coolwarm       2     0(0.00%) |   1314     883    1745    883 |    0.10        0.00
# GET      /tiles/WebMercatorQuad/1/0/1?concept_id=C2723754850-GES_DISC&variable=precipitation&datetime=2024-02-11T00%3A00%3A00Z&backend=xarray&scale=1&return_mask=true&rescale=0%2C455&colormap_name=coolwarm       2     0(0.00%) |   1498     985    2011    990 |    0.20        0.00
# GET      /tiles/WebMercatorQuad/1/1/0?concept_id=C2723754850-GES_DISC&variable=precipitation&datetime=2024-02-11T00%3A00%3A00Z&backend=xarray&scale=1&return_mask=true&rescale=0%2C455&colormap_name=coolwarm       4     0(0.00%) |   1019     870    1432    880 |    0.30        0.00
# GET      /tiles/WebMercatorQuad/1/1/1?concept_id=C2723754850-GES_DISC&variable=precipitation&datetime=2024-02-11T00%3A00%3A00Z&backend=xarray&scale=1&return_mask=true&rescale=0%2C455&colormap_name=coolwarm       2     0(0.00%) |   1768    1010    2526   1010 |    0.10        0.00
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated                                                                        20     0(0.00%) |   2549     870   11196   2500 |    0.70        0.00
#
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# GET      /tiles/WebMercatorQuad/0/0/0?concept_id=C2723754850-GES_DISC&variable=precipitation&datetime=2024-02-11T00%3A00%3A00Z&backend=xarray&scale=1&return_mask=true&rescale=0%2C455&colormap_name=coolwarm      10     0(0.00%) |   3775    2670   11196   2900 |    0.00        0.00
# GET      /tiles/WebMercatorQuad/1/0/0?concept_id=C2723754850-GES_DISC&variable=precipitation&datetime=2024-02-11T00%3A00%3A00Z&backend=xarray&scale=1&return_mask=true&rescale=0%2C455&colormap_name=coolwarm       2     0(0.00%) |   1314     883    1745    883 |    0.20        0.00
# GET      /tiles/WebMercatorQuad/1/0/1?concept_id=C2723754850-GES_DISC&variable=precipitation&datetime=2024-02-11T00%3A00%3A00Z&backend=xarray&scale=1&return_mask=true&rescale=0%2C455&colormap_name=coolwarm       2     0(0.00%) |   1498     985    2011    990 |    0.20        0.00
# GET      /tiles/WebMercatorQuad/1/1/0?concept_id=C2723754850-GES_DISC&variable=precipitation&datetime=2024-02-11T00%3A00%3A00Z&backend=xarray&scale=1&return_mask=true&rescale=0%2C455&colormap_name=coolwarm       4     0(0.00%) |   1019     870    1432    880 |    0.20        0.00
# GET      /tiles/WebMercatorQuad/1/1/1?concept_id=C2723754850-GES_DISC&variable=precipitation&datetime=2024-02-11T00%3A00%3A00Z&backend=xarray&scale=1&return_mask=true&rescale=0%2C455&colormap_name=coolwarm       2     0(0.00%) |   1768    1010    2526   1010 |    0.20        0.00
# GET      /tiles/WebMercatorQuad/2/0/1?concept_id=C2723754850-GES_DISC&variable=precipitation&datetime=2024-02-11T00%3A00%3A00Z&backend=xarray&scale=1&return_mask=true&rescale=0%2C455&colormap_name=coolwarm       1     0(0.00%) |   1193    1193    1193   1193 |    0.00        0.00
# GET      /tiles/WebMercatorQuad/2/2/1?concept_id=C2723754850-GES_DISC&variable=precipitation&datetime=2024-02-11T00%3A00%3A00Z&backend=xarray&scale=1&return_mask=true&rescale=0%2C455&colormap_name=coolwarm       1     0(0.00%) |   1145    1145    1145   1145 |    0.00        0.00
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated                                                                        22     0(0.00%) |   2424     870   11196   2000 |    0.80        0.00
#
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# GET      /tiles/WebMercatorQuad/0/0/0?concept_id=C2723754850-GES_DISC&variable=precipitation&datetime=2024-02-11T00%3A00%3A00Z&backend=xarray&scale=1&return_mask=true&rescale=0%2C455&colormap_name=coolwarm      10     0(0.00%) |   3775    2670   11196   2900 |    0.00        0.00
# GET      /tiles/WebMercatorQuad/1/0/0?concept_id=C2723754850-GES_DISC&variable=precipitation&datetime=2024-02-11T00%3A00%3A00Z&backend=xarray&scale=1&return_mask=true&rescale=0%2C455&colormap_name=coolwarm       2     0(0.00%) |   1314     883    1745    883 |    0.10        0.00
# GET      /tiles/WebMercatorQuad/1/0/1?concept_id=C2723754850-GES_DISC&variable=precipitation&datetime=2024-02-11T00%3A00%3A00Z&backend=xarray&scale=1&return_mask=true&rescale=0%2C455&colormap_name=coolwarm       2     0(0.00%) |   1498     985    2011    990 |    0.20        0.00
# GET      /tiles/WebMercatorQuad/1/1/0?concept_id=C2723754850-GES_DISC&variable=precipitation&datetime=2024-02-11T00%3A00%3A00Z&backend=xarray&scale=1&return_mask=true&rescale=0%2C455&colormap_name=coolwarm       4     0(0.00%) |   1019     870    1432    880 |    0.20        0.00
# GET      /tiles/WebMercatorQuad/1/1/1?concept_id=C2723754850-GES_DISC&variable=precipitation&datetime=2024-02-11T00%3A00%3A00Z&backend=xarray&scale=1&return_mask=true&rescale=0%2C455&colormap_name=coolwarm       2     0(0.00%) |   1768    1010    2526   1010 |    0.20        0.00
# GET      /tiles/WebMercatorQuad/2/0/1?concept_id=C2723754850-GES_DISC&variable=precipitation&datetime=2024-02-11T00%3A00%3A00Z&backend=xarray&scale=1&return_mask=true&rescale=0%2C455&colormap_name=coolwarm       1     0(0.00%) |   1193    1193    1193   1193 |    0.00        0.00
# GET      /tiles/WebMercatorQuad/2/2/1?concept_id=C2723754850-GES_DISC&variable=precipitation&datetime=2024-02-11T00%3A00%3A00Z&backend=xarray&scale=1&return_mask=true&rescale=0%2C455&colormap_name=coolwarm       1     0(0.00%) |   1145    1145    1145   1145 |    0.10        0.00
# GET      /tiles/WebMercatorQuad/2/3/1?concept_id=C2723754850-GES_DISC&variable=precipitation&datetime=2024-02-11T00%3A00%3A00Z&backend=xarray&scale=1&return_mask=true&rescale=0%2C455&colormap_name=coolwarm       1     0(0.00%) |   1801    1801    1801   1801 |    0.00        0.00
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated                                                                        23     0(0.00%) |   2397     870   11196   2000 |    0.80        0.00
#
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# GET      /tiles/WebMercatorQuad/0/0/0?concept_id=C2723754850-GES_DISC&variable=precipitation&datetime=2024-02-11T00%3A00%3A00Z&backend=xarray&scale=1&return_mask=true&rescale=0%2C455&colormap_name=coolwarm      10     0(0.00%) |   3775    2670   11196   2900 |    0.00        0.00
# GET      /tiles/WebMercatorQuad/1/0/0?concept_id=C2723754850-GES_DISC&variable=precipitation&datetime=2024-02-11T00%3A00%3A00Z&backend=xarray&scale=1&return_mask=true&rescale=0%2C455&colormap_name=coolwarm       2     0(0.00%) |   1314     883    1745    883 |    0.10        0.00
# GET      /tiles/WebMercatorQuad/1/0/1?concept_id=C2723754850-GES_DISC&variable=precipitation&datetime=2024-02-11T00%3A00%3A00Z&backend=xarray&scale=1&return_mask=true&rescale=0%2C455&colormap_name=coolwarm       2     0(0.00%) |   1498     985    2011    990 |    0.20        0.00
# GET      /tiles/WebMercatorQuad/1/1/0?concept_id=C2723754850-GES_DISC&variable=precipitation&datetime=2024-02-11T00%3A00%3A00Z&backend=xarray&scale=1&return_mask=true&rescale=0%2C455&colormap_name=coolwarm       4     0(0.00%) |   1019     870    1432    880 |    0.20        0.00
# GET      /tiles/WebMercatorQuad/1/1/1?concept_id=C2723754850-GES_DISC&variable=precipitation&datetime=2024-02-11T00%3A00%3A00Z&backend=xarray&scale=1&return_mask=true&rescale=0%2C455&colormap_name=coolwarm       2     0(0.00%) |   1768    1010    2526   1010 |    0.10        0.00
# GET      /tiles/WebMercatorQuad/2/0/1?concept_id=C2723754850-GES_DISC&variable=precipitation&datetime=2024-02-11T00%3A00%3A00Z&backend=xarray&scale=1&return_mask=true&rescale=0%2C455&colormap_name=coolwarm       1     0(0.00%) |   1193    1193    1193   1193 |    0.10        0.00
# GET      /tiles/WebMercatorQuad/2/1/2?concept_id=C2723754850-GES_DISC&variable=precipitation&datetime=2024-02-11T00%3A00%3A00Z&backend=xarray&scale=1&return_mask=true&rescale=0%2C455&colormap_name=coolwarm       1     0(0.00%) |   1518    1518    1518   1518 |    0.00        0.00
# GET      /tiles/WebMercatorQuad/2/2/1?concept_id=C2723754850-GES_DISC&variable=precipitation&datetime=2024-02-11T00%3A00%3A00Z&backend=xarray&scale=1&return_mask=true&rescale=0%2C455&colormap_name=coolwarm       1     0(0.00%) |   1145    1145    1145   1145 |    0.10        0.00
# GET      /tiles/WebMercatorQuad/2/3/1?concept_id=C2723754850-GES_DISC&variable=precipitation&datetime=2024-02-11T00%3A00%3A00Z&backend=xarray&scale=1&return_mask=true&rescale=0%2C455&colormap_name=coolwarm       1     0(0.00%) |   1801    1801    1801   1801 |    0.00        0.00
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated                                                                        24     0(0.00%) |   2360     870   11196   1800 |    0.80        0.00
#
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# GET      /tiles/WebMercatorQuad/0/0/0?concept_id=C2723754850-GES_DISC&variable=precipitation&datetime=2024-02-11T00%3A00%3A00Z&backend=xarray&scale=1&return_mask=true&rescale=0%2C455&colormap_name=coolwarm      10     0(0.00%) |   3775    2670   11196   2900 |    0.00        0.00
# GET      /tiles/WebMercatorQuad/1/0/0?concept_id=C2723754850-GES_DISC&variable=precipitation&datetime=2024-02-11T00%3A00%3A00Z&backend=xarray&scale=1&return_mask=true&rescale=0%2C455&colormap_name=coolwarm       2     0(0.00%) |   1314     883    1745    883 |    0.10        0.00
# GET      /tiles/WebMercatorQuad/1/0/1?concept_id=C2723754850-GES_DISC&variable=precipitation&datetime=2024-02-11T00%3A00%3A00Z&backend=xarray&scale=1&return_mask=true&rescale=0%2C455&colormap_name=coolwarm       2     0(0.00%) |   1498     985    2011    990 |    0.10        0.00
# GET      /tiles/WebMercatorQuad/1/1/0?concept_id=C2723754850-GES_DISC&variable=precipitation&datetime=2024-02-11T00%3A00%3A00Z&backend=xarray&scale=1&return_mask=true&rescale=0%2C455&colormap_name=coolwarm       4     0(0.00%) |   1019     870    1432    880 |    0.20        0.00
# GET      /tiles/WebMercatorQuad/1/1/1?concept_id=C2723754850-GES_DISC&variable=precipitation&datetime=2024-02-11T00%3A00%3A00Z&backend=xarray&scale=1&return_mask=true&rescale=0%2C455&colormap_name=coolwarm       2     0(0.00%) |   1768    1010    2526   1010 |    0.10        0.00
# GET      /tiles/WebMercatorQuad/2/0/1?concept_id=C2723754850-GES_DISC&variable=precipitation&datetime=2024-02-11T00%3A00%3A00Z&backend=xarray&scale=1&return_mask=true&rescale=0%2C455&colormap_name=coolwarm       1     0(0.00%) |   1193    1193    1193   1193 |    0.10        0.00
# GET      /tiles/WebMercatorQuad/2/1/1?concept_id=C2723754850-GES_DISC&variable=precipitation&datetime=2024-02-11T00%3A00%3A00Z&backend=xarray&scale=1&return_mask=true&rescale=0%2C455&colormap_name=coolwarm       2     0(0.00%) |   1020     677    1362    680 |    0.00        0.00
# GET      /tiles/WebMercatorQuad/2/1/2?concept_id=C2723754850-GES_DISC&variable=precipitation&datetime=2024-02-11T00%3A00%3A00Z&backend=xarray&scale=1&return_mask=true&rescale=0%2C455&colormap_name=coolwarm       2     0(0.00%) |   1120     721    1518    721 |    0.00        0.00
# GET      /tiles/WebMercatorQuad/2/2/1?concept_id=C2723754850-GES_DISC&variable=precipitation&datetime=2024-02-11T00%3A00%3A00Z&backend=xarray&scale=1&return_mask=true&rescale=0%2C455&colormap_name=coolwarm       1     0(0.00%) |   1145    1145    1145   1145 |    0.10        0.00
# GET      /tiles/WebMercatorQuad/2/3/1?concept_id=C2723754850-GES_DISC&variable=precipitation&datetime=2024-02-11T00%3A00%3A00Z&backend=xarray&scale=1&return_mask=true&rescale=0%2C455&colormap_name=coolwarm       1     0(0.00%) |   1801    1801    1801   1801 |    0.10        0.00
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated                                                                        27     0(0.00%) |   2200     677   11196   1700 |    0.80        0.00
#
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# GET      /tiles/WebMercatorQuad/0/0/0?concept_id=C2723754850-GES_DISC&variable=precipitation&datetime=2024-02-11T00%3A00%3A00Z&backend=xarray&scale=1&return_mask=true&rescale=0%2C455&colormap_name=coolwarm      10     0(0.00%) |   3775    2670   11196   2900 |    0.00        0.00
# GET      /tiles/WebMercatorQuad/1/0/0?concept_id=C2723754850-GES_DISC&variable=precipitation&datetime=2024-02-11T00%3A00%3A00Z&backend=xarray&scale=1&return_mask=true&rescale=0%2C455&colormap_name=coolwarm       2     0(0.00%) |   1314     883    1745    883 |    0.00        0.00
# GET      /tiles/WebMercatorQuad/1/0/1?concept_id=C2723754850-GES_DISC&variable=precipitation&datetime=2024-02-11T00%3A00%3A00Z&backend=xarray&scale=1&return_mask=true&rescale=0%2C455&colormap_name=coolwarm       2     0(0.00%) |   1498     985    2011    990 |    0.00        0.00
# GET      /tiles/WebMercatorQuad/1/1/0?concept_id=C2723754850-GES_DISC&variable=precipitation&datetime=2024-02-11T00%3A00%3A00Z&backend=xarray&scale=1&return_mask=true&rescale=0%2C455&colormap_name=coolwarm       4     0(0.00%) |   1019     870    1432    880 |    0.10        0.00
# GET      /tiles/WebMercatorQuad/1/1/1?concept_id=C2723754850-GES_DISC&variable=precipitation&datetime=2024-02-11T00%3A00%3A00Z&backend=xarray&scale=1&return_mask=true&rescale=0%2C455&colormap_name=coolwarm       2     0(0.00%) |   1768    1010    2526   1010 |    0.10        0.00
# GET      /tiles/WebMercatorQuad/2/0/1?concept_id=C2723754850-GES_DISC&variable=precipitation&datetime=2024-02-11T00%3A00%3A00Z&backend=xarray&scale=1&return_mask=true&rescale=0%2C455&colormap_name=coolwarm       1     0(0.00%) |   1193    1193    1193   1193 |    0.10        0.00
# GET      /tiles/WebMercatorQuad/2/0/3?concept_id=C2723754850-GES_DISC&variable=precipitation&datetime=2024-02-11T00%3A00%3A00Z&backend=xarray&scale=1&return_mask=true&rescale=0%2C455&colormap_name=coolwarm       1     0(0.00%) |   1129    1129    1129   1129 |    0.00        0.00
# GET      /tiles/WebMercatorQuad/2/1/1?concept_id=C2723754850-GES_DISC&variable=precipitation&datetime=2024-02-11T00%3A00%3A00Z&backend=xarray&scale=1&return_mask=true&rescale=0%2C455&colormap_name=coolwarm       2     0(0.00%) |   1020     677    1362    680 |    0.20        0.00
# GET      /tiles/WebMercatorQuad/2/1/2?concept_id=C2723754850-GES_DISC&variable=precipitation&datetime=2024-02-11T00%3A00%3A00Z&backend=xarray&scale=1&return_mask=true&rescale=0%2C455&colormap_name=coolwarm       2     0(0.00%) |   1120     721    1518    721 |    0.20        0.00
# GET      /tiles/WebMercatorQuad/2/2/1?concept_id=C2723754850-GES_DISC&variable=precipitation&datetime=2024-02-11T00%3A00%3A00Z&backend=xarray&scale=1&return_mask=true&rescale=0%2C455&colormap_name=coolwarm       1     0(0.00%) |   1145    1145    1145   1145 |    0.10        0.00
# GET      /tiles/WebMercatorQuad/2/2/3?concept_id=C2723754850-GES_DISC&variable=precipitation&datetime=2024-02-11T00%3A00%3A00Z&backend=xarray&scale=1&return_mask=true&rescale=0%2C455&colormap_name=coolwarm       1     0(0.00%) |   1087    1087    1087   1087 |    0.00        0.00
# GET      /tiles/WebMercatorQuad/2/3/1?concept_id=C2723754850-GES_DISC&variable=precipitation&datetime=2024-02-11T00%3A00%3A00Z&backend=xarray&scale=1&return_mask=true&rescale=0%2C455&colormap_name=coolwarm       1     0(0.00%) |   1801    1801    1801   1801 |    0.10        0.00
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated                                                                        29     0(0.00%) |   2125     677   11196   1500 |    0.90        0.00
#
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# GET      /tiles/WebMercatorQuad/0/0/0?concept_id=C2723754850-GES_DISC&variable=precipitation&datetime=2024-02-11T00%3A00%3A00Z&backend=xarray&scale=1&return_mask=true&rescale=0%2C455&colormap_name=coolwarm      10     0(0.00%) |   3775    2670   11196   2900 |    0.00        0.00
# GET      /tiles/WebMercatorQuad/1/0/0?concept_id=C2723754850-GES_DISC&variable=precipitation&datetime=2024-02-11T00%3A00%3A00Z&backend=xarray&scale=1&return_mask=true&rescale=0%2C455&colormap_name=coolwarm       2     0(0.00%) |   1314     883    1745    883 |    0.00        0.00
# GET      /tiles/WebMercatorQuad/1/0/1?concept_id=C2723754850-GES_DISC&variable=precipitation&datetime=2024-02-11T00%3A00%3A00Z&backend=xarray&scale=1&return_mask=true&rescale=0%2C455&colormap_name=coolwarm       2     0(0.00%) |   1498     985    2011    990 |    0.00        0.00
# GET      /tiles/WebMercatorQuad/1/1/0?concept_id=C2723754850-GES_DISC&variable=precipitation&datetime=2024-02-11T00%3A00%3A00Z&backend=xarray&scale=1&return_mask=true&rescale=0%2C455&colormap_name=coolwarm       4     0(0.00%) |   1019     870    1432    880 |    0.10        0.00
# GET      /tiles/WebMercatorQuad/1/1/1?concept_id=C2723754850-GES_DISC&variable=precipitation&datetime=2024-02-11T00%3A00%3A00Z&backend=xarray&scale=1&return_mask=true&rescale=0%2C455&colormap_name=coolwarm       2     0(0.00%) |   1768    1010    2526   1010 |    0.00        0.00
# GET      /tiles/WebMercatorQuad/2/0/1?concept_id=C2723754850-GES_DISC&variable=precipitation&datetime=2024-02-11T00%3A00%3A00Z&backend=xarray&scale=1&return_mask=true&rescale=0%2C455&colormap_name=coolwarm       1     0(0.00%) |   1193    1193    1193   1193 |    0.10        0.00
# GET      /tiles/WebMercatorQuad/2/0/2?concept_id=C2723754850-GES_DISC&variable=precipitation&datetime=2024-02-11T00%3A00%3A00Z&backend=xarray&scale=1&return_mask=true&rescale=0%2C455&colormap_name=coolwarm       1     0(0.00%) |   1220    1220    1220   1220 |    0.00        0.00
# ...
# GET      /tiles/WebMercatorQuad/4/3/5?concept_id=C2723754850-GES_DISC&variable=precipitation&datetime=2024-02-11T00%3A00%3A00Z&backend=xarray&scale=1&return_mask=true&rescale=0%2C455&colormap_name=coolwarm     1200   1200   1200   1200   1200   1200   1200   1200   1200   1200   1200      1
# GET      /tiles/WebMercatorQuad/4/8/7?concept_id=C2723754850-GES_DISC&variable=precipitation&datetime=2024-02-11T00%3A00%3A00Z&backend=xarray&scale=1&return_mask=true&rescale=0%2C455&colormap_name=coolwarm     1400   1400   1400   1400   1400   1400   1400   1400   1400   1400   1400      1
# GET      /tiles/WebMercatorQuad/4/9/9?concept_id=C2723754850-GES_DISC&variable=precipitation&datetime=2024-02-11T00%3A00%3A00Z&backend=xarray&scale=1&return_mask=true&rescale=0%2C455&colormap_name=coolwarm      940    940    940    940    940    940    940    940    940    940    940      1
# GET      /tiles/WebMercatorQuad/5/12/24?concept_id=C2723754850-GES_DISC&variable=precipitation&datetime=2024-02-11T00%3A00%3A00Z&backend=xarray&scale=1&return_mask=true&rescale=0%2C455&colormap_name=coolwarm     1300   1300   1300   1300   1300   1300   1300   1300   1300   1300   1300      1
# GET      /tiles/WebMercatorQuad/5/14/22?concept_id=C2723754850-GES_DISC&variable=precipitation&datetime=2024-02-11T00%3A00%3A00Z&backend=xarray&scale=1&return_mask=true&rescale=0%2C455&colormap_name=coolwarm     1300   1300   1300   1300   1300   1300   1300   1300   1300   1300   1300      1
# GET      /tiles/WebMercatorQuad/5/15/21?concept_id=C2723754850-GES_DISC&variable=precipitation&datetime=2024-02-11T00%3A00%3A00Z&backend=xarray&scale=1&return_mask=true&rescale=0%2C455&colormap_name=coolwarm     1100   1100   1100   1100   1100   1100   1100   1100   1100   1100   1100      1
# GET      /tiles/WebMercatorQuad/5/15/26?concept_id=C2723754850-GES_DISC&variable=precipitation&datetime=2024-02-11T00%3A00%3A00Z&backend=xarray&scale=1&return_mask=true&rescale=0%2C455&colormap_name=coolwarm     1600   1600   1600   1600   1600   1600   1600   1600   1600   1600   1600      1
# GET      /tiles/WebMercatorQuad/5/19/7?concept_id=C2723754850-GES_DISC&variable=precipitation&datetime=2024-02-11T00%3A00%3A00Z&backend=xarray&scale=1&return_mask=true&rescale=0%2C455&colormap_name=coolwarm     1000   1000   1000   1000   1000   1000   1000   1000   1000   1000   1000      1
# GET      /tiles/WebMercatorQuad/5/21/20?concept_id=C2723754850-GES_DISC&variable=precipitation&datetime=2024-02-11T00%3A00%3A00Z&backend=xarray&scale=1&return_mask=true&rescale=0%2C455&colormap_name=coolwarm     1200   1200   1200   1200   1200   1200   1200   1200   1200   1200   1200      1
# GET      /tiles/WebMercatorQuad/5/22/11?concept_id=C2723754850-GES_DISC&variable=precipitation&datetime=2024-02-11T00%3A00%3A00Z&backend=xarray&scale=1&return_mask=true&rescale=0%2C455&colormap_name=coolwarm      920    920    920    920    920    920    920    920    920    920    920      1
# GET      /tiles/WebMercatorQuad/5/3/13?concept_id=C2723754850-GES_DISC&variable=precipitation&datetime=2024-02-11T00%3A00%3A00Z&backend=xarray&scale=1&return_mask=true&rescale=0%2C455&colormap_name=coolwarm     1000   1000   1000   1000   1000   1000   1000   1000   1000   1000   1000      1
# GET      /tiles/WebMercatorQuad/5/30/14?concept_id=C2723754850-GES_DISC&variable=precipitation&datetime=2024-02-11T00%3A00%3A00Z&backend=xarray&scale=1&return_mask=true&rescale=0%2C455&colormap_name=coolwarm      990    990    990    990    990    990    990    990    990    990    990      1
# GET      /tiles/WebMercatorQuad/5/9/16?concept_id=C2723754850-GES_DISC&variable=precipitation&datetime=2024-02-11T00%3A00%3A00Z&backend=xarray&scale=1&return_mask=true&rescale=0%2C455&colormap_name=coolwarm     1600   1600   1600   1600   1600   1600   1600   1600   1600   1600   1600      1
# GET      /tiles/WebMercatorQuad/6/1/34?concept_id=C2723754850-GES_DISC&variable=precipitation&datetime=2024-02-11T00%3A00%3A00Z&backend=xarray&scale=1&return_mask=true&rescale=0%2C455&colormap_name=coolwarm      930    930    930    930    930    930    930    930    930    930    930      1
# GET      /tiles/WebMercatorQuad/6/12/44?concept_id=C2723754850-GES_DISC&variable=precipitation&datetime=2024-02-11T00%3A00%3A00Z&backend=xarray&scale=1&return_mask=true&rescale=0%2C455&colormap_name=coolwarm     1700   1700   1700   1700   1700   1700   1700   1700   1700   1700   1700      1
# GET      /tiles/WebMercatorQuad/6/21/48?concept_id=C2723754850-GES_DISC&variable=precipitation&datetime=2024-02-11T00%3A00%3A00Z&backend=xarray&scale=1&return_mask=true&rescale=0%2C455&colormap_name=coolwarm     1000   1000   1000   1000   1000   1000   1000   1000   1000   1000   1000      1
# GET      /tiles/WebMercatorQuad/6/28/24?concept_id=C2723754850-GES_DISC&variable=precipitation&datetime=2024-02-11T00%3A00%3A00Z&backend=xarray&scale=1&return_mask=true&rescale=0%2C455&colormap_name=coolwarm      950    950    950    950    950    950    950    950    950    950    950      1
# GET      /tiles/WebMercatorQuad/6/46/1?concept_id=C2723754850-GES_DISC&variable=precipitation&datetime=2024-02-11T00%3A00%3A00Z&backend=xarray&scale=1&return_mask=true&rescale=0%2C455&colormap_name=coolwarm      900    900    900    900    900    900    900    900    900    900    900      1
# GET      /tiles/WebMercatorQuad/6/46/26?concept_id=C2723754850-GES_DISC&variable=precipitation&datetime=2024-02-11T00%3A00%3A00Z&backend=xarray&scale=1&return_mask=true&rescale=0%2C455&colormap_name=coolwarm      930    930    930    930    930    930    930    930    930    930    930      1
# GET      /tiles/WebMercatorQuad/6/50/28?concept_id=C2723754850-GES_DISC&variable=precipitation&datetime=2024-02-11T00%3A00%3A00Z&backend=xarray&scale=1&return_mask=true&rescale=0%2C455&colormap_name=coolwarm     1300   1300   1300   1300   1300   1300   1300   1300   1300   1300   1300      1
# GET      /tiles/WebMercatorQuad/6/52/31?concept_id=C2723754850-GES_DISC&variable=precipitation&datetime=2024-02-11T00%3A00%3A00Z&backend=xarray&scale=1&return_mask=true&rescale=0%2C455&colormap_name=coolwarm     1000   1000   1000   1000   1000   1000   1000   1000   1000   1000   1000      1
# GET      /tiles/WebMercatorQuad/6/55/19?concept_id=C2723754850-GES_DISC&variable=precipitation&datetime=2024-02-11T00%3A00%3A00Z&backend=xarray&scale=1&return_mask=true&rescale=0%2C455&colormap_name=coolwarm     1100   1100   1100   1100   1100   1100   1100   1100   1100   1100   1100      1
# GET      /tiles/WebMercatorQuad/6/6/38?concept_id=C2723754850-GES_DISC&variable=precipitation&datetime=2024-02-11T00%3A00%3A00Z&backend=xarray&scale=1&return_mask=true&rescale=0%2C455&colormap_name=coolwarm     1000   1000   1000   1000   1000   1000   1000   1000   1000   1000   1000      1
# GET      /tiles/WebMercatorQuad/7/108/89?concept_id=C2723754850-GES_DISC&variable=precipitation&datetime=2024-02-11T00%3A00%3A00Z&backend=xarray&scale=1&return_mask=true&rescale=0%2C455&colormap_name=coolwarm     1400   1400   1400   1400   1400   1400   1400   1400   1400   1400   1400      1
# GET      /tiles/WebMercatorQuad/7/115/80?concept_id=C2723754850-GES_DISC&variable=precipitation&datetime=2024-02-11T00%3A00%3A00Z&backend=xarray&scale=1&return_mask=true&rescale=0%2C455&colormap_name=coolwarm     1400   1400   1400   1400   1400   1400   1400   1400   1400   1400   1400      1
# GET      /tiles/WebMercatorQuad/7/37/50?concept_id=C2723754850-GES_DISC&variable=precipitation&datetime=2024-02-11T00%3A00%3A00Z&backend=xarray&scale=1&return_mask=true&rescale=0%2C455&colormap_name=coolwarm      880    880    880    880    880    880    880    880    880    880    880      1
# GET      /tiles/WebMercatorQuad/7/47/76?concept_id=C2723754850-GES_DISC&variable=precipitation&datetime=2024-02-11T00%3A00%3A00Z&backend=xarray&scale=1&return_mask=true&rescale=0%2C455&colormap_name=coolwarm      910    910    910    910    910    910    910    910    910    910    910      1
# GET      /tiles/WebMercatorQuad/7/52/51?concept_id=C2723754850-GES_DISC&variable=precipitation&datetime=2024-02-11T00%3A00%3A00Z&backend=xarray&scale=1&return_mask=true&rescale=0%2C455&colormap_name=coolwarm     1200   1200   1200   1200   1200   1200   1200   1200   1200   1200   1200      1
# GET      /tiles/WebMercatorQuad/7/60/99?concept_id=C2723754850-GES_DISC&variable=precipitation&datetime=2024-02-11T00%3A00%3A00Z&backend=xarray&scale=1&return_mask=true&rescale=0%2C455&colormap_name=coolwarm     1400   1400   1400   1400   1400   1400   1400   1400   1400   1400   1400      1
# GET      /tiles/WebMercatorQuad/7/67/59?concept_id=C2723754850-GES_DISC&variable=precipitation&datetime=2024-02-11T00%3A00%3A00Z&backend=xarray&scale=1&return_mask=true&rescale=0%2C455&colormap_name=coolwarm     1400   1400   1400   1400   1400   1400   1400   1400   1400   1400   1400      1
# GET      /tiles/WebMercatorQuad/7/81/89?concept_id=C2723754850-GES_DISC&variable=precipitation&datetime=2024-02-11T00%3A00%3A00Z&backend=xarray&scale=1&return_mask=true&rescale=0%2C455&colormap_name=coolwarm     1400   1400   1400   1400   1400   1400   1400   1400   1400   1400   1400      1
# GET      /tiles/WebMercatorQuad/7/85/48?concept_id=C2723754850-GES_DISC&variable=precipitation&datetime=2024-02-11T00%3A00%3A00Z&backend=xarray&scale=1&return_mask=true&rescale=0%2C455&colormap_name=coolwarm     1100   1100   1100   1100   1100   1100   1100   1100   1100   1100   1100      1
# GET      /tiles/WebMercatorQuad/7/96/70?concept_id=C2723754850-GES_DISC&variable=precipitation&datetime=2024-02-11T00%3A00%3A00Z&backend=xarray&scale=1&return_mask=true&rescale=0%2C455&colormap_name=coolwarm     1200   1200   1200   1200   1200   1200   1200   1200   1200   1200   1200      1
# GET      /tiles/WebMercatorQuad/8/148/98?concept_id=C2723754850-GES_DISC&variable=precipitation&datetime=2024-02-11T00%3A00%3A00Z&backend=xarray&scale=1&return_mask=true&rescale=0%2C455&colormap_name=coolwarm      900    900    900    900    900    900    900    900    900    900    900      1
# GET      /tiles/WebMercatorQuad/8/162/128?concept_id=C2723754850-GES_DISC&variable=precipitation&datetime=2024-02-11T00%3A00%3A00Z&backend=xarray&scale=1&return_mask=true&rescale=0%2C455&colormap_name=coolwarm     1200   1200   1200   1200   1200   1200   1200   1200   1200   1200   1200      1
# GET      /tiles/WebMercatorQuad/8/177/213?concept_id=C2723754850-GES_DISC&variable=precipitation&datetime=2024-02-11T00%3A00%3A00Z&backend=xarray&scale=1&return_mask=true&rescale=0%2C455&colormap_name=coolwarm     1300   1300   1300   1300   1300   1300   1300   1300   1300   1300   1300      1
# GET      /tiles/WebMercatorQuad/8/199/111?concept_id=C2723754850-GES_DISC&variable=precipitation&datetime=2024-02-11T00%3A00%3A00Z&backend=xarray&scale=1&return_mask=true&rescale=0%2C455&colormap_name=coolwarm     1100   1100   1100   1100   1100   1100   1100   1100   1100   1100   1100      1
# GET      /tiles/WebMercatorQuad/8/231/178?concept_id=C2723754850-GES_DISC&variable=precipitation&datetime=2024-02-11T00%3A00%3A00Z&backend=xarray&scale=1&return_mask=true&rescale=0%2C455&colormap_name=coolwarm      930    930    930    930    930    930    930    930    930    930    930      1
# GET      /tiles/WebMercatorQuad/8/250/160?concept_id=C2723754850-GES_DISC&variable=precipitation&datetime=2024-02-11T00%3A00%3A00Z&backend=xarray&scale=1&return_mask=true&rescale=0%2C455&colormap_name=coolwarm      920    920    920    920    920    920    920    920    920    920    920      1
# GET      /tiles/WebMercatorQuad/8/49/123?concept_id=C2723754850-GES_DISC&variable=precipitation&datetime=2024-02-11T00%3A00%3A00Z&backend=xarray&scale=1&return_mask=true&rescale=0%2C455&colormap_name=coolwarm     1500   1500   1500   1500   1500   1500   1500   1500   1500   1500   1500      1
# GET      /tiles/WebMercatorQuad/8/49/132?concept_id=C2723754850-GES_DISC&variable=precipitation&datetime=2024-02-11T00%3A00%3A00Z&backend=xarray&scale=1&return_mask=true&rescale=0%2C455&colormap_name=coolwarm     1700   1700   1700   1700   1700   1700   1700   1700   1700   1700   1700      1
# GET      /tiles/WebMercatorQuad/8/5/120?concept_id=C2723754850-GES_DISC&variable=precipitation&datetime=2024-02-11T00%3A00%3A00Z&backend=xarray&scale=1&return_mask=true&rescale=0%2C455&colormap_name=coolwarm      950    950    950    950    950    950    950    950    950    950    950      1
# GET      /tiles/WebMercatorQuad/8/74/94?concept_id=C2723754850-GES_DISC&variable=precipitation&datetime=2024-02-11T00%3A00%3A00Z&backend=xarray&scale=1&return_mask=true&rescale=0%2C455&colormap_name=coolwarm      960    960    960    960    960    960    960    960    960    960    960      1
# GET      /tiles/WebMercatorQuad/9/106/177?concept_id=C2723754850-GES_DISC&variable=precipitation&datetime=2024-02-11T00%3A00%3A00Z&backend=xarray&scale=1&return_mask=true&rescale=0%2C455&colormap_name=coolwarm      960    960    960    960    960    960    960    960    960    960    960      1
# GET      /tiles/WebMercatorQuad/9/110/264?concept_id=C2723754850-GES_DISC&variable=precipitation&datetime=2024-02-11T00%3A00%3A00Z&backend=xarray&scale=1&return_mask=true&rescale=0%2C455&colormap_name=coolwarm      940    940    940    940    940    940    940    940    940    940    940      1
# GET      /tiles/WebMercatorQuad/9/177/28?concept_id=C2723754850-GES_DISC&variable=precipitation&datetime=2024-02-11T00%3A00%3A00Z&backend=xarray&scale=1&return_mask=true&rescale=0%2C455&colormap_name=coolwarm     1000   1000   1000   1000   1000   1000   1000   1000   1000   1000   1000      1
# GET      /tiles/WebMercatorQuad/9/18/283?concept_id=C2723754850-GES_DISC&variable=precipitation&datetime=2024-02-11T00%3A00%3A00Z&backend=xarray&scale=1&return_mask=true&rescale=0%2C455&colormap_name=coolwarm     1900   1900   1900   1900   1900   1900   1900   1900   1900   1900   1900      1
# GET      /tiles/WebMercatorQuad/9/192/263?concept_id=C2723754850-GES_DISC&variable=precipitation&datetime=2024-02-11T00%3A00%3A00Z&backend=xarray&scale=1&return_mask=true&rescale=0%2C455&colormap_name=coolwarm     1800   1800   1800   1800   1800   1800   1800   1800   1800   1800   1800      1
# GET      /tiles/WebMercatorQuad/9/25/268?concept_id=C2723754850-GES_DISC&variable=precipitation&datetime=2024-02-11T00%3A00%3A00Z&backend=xarray&scale=1&return_mask=true&rescale=0%2C455&colormap_name=coolwarm      940    940    940    940    940    940    940    940    940    940    940      1
# GET      /tiles/WebMercatorQuad/9/347/279?concept_id=C2723754850-GES_DISC&variable=precipitation&datetime=2024-02-11T00%3A00%3A00Z&backend=xarray&scale=1&return_mask=true&rescale=0%2C455&colormap_name=coolwarm     1300   1300   1300   1300   1300   1300   1300   1300   1300   1300   1300      1
# GET      /tiles/WebMercatorQuad/9/348/126?concept_id=C2723754850-GES_DISC&variable=precipitation&datetime=2024-02-11T00%3A00%3A00Z&backend=xarray&scale=1&return_mask=true&rescale=0%2C455&colormap_name=coolwarm     1100   1100   1100   1100   1100   1100   1100   1100   1100   1100   1100      1
# GET      /tiles/WebMercatorQuad/9/369/258?concept_id=C2723754850-GES_DISC&variable=precipitation&datetime=2024-02-11T00%3A00%3A00Z&backend=xarray&scale=1&return_mask=true&rescale=0%2C455&colormap_name=coolwarm      920    920    920    920    920    920    920    920    920    920    920      1
# GET      /tiles/WebMercatorQuad/9/416/169?concept_id=C2723754850-GES_DISC&variable=precipitation&datetime=2024-02-11T00%3A00%3A00Z&backend=xarray&scale=1&return_mask=true&rescale=0%2C455&colormap_name=coolwarm     1600   1600   1600   1600   1600   1600   1600   1600   1600   1600   1600      1
# --------|--------------------------------------------------------------------------------|--------|------|------|------|------|------|------|------|------|------|------|------
#          Aggregated                                                                           1200   1400   1500   1600   1900   2700   3100   3100  11000  11000  11000    210
# 0

# %% [markdown]
# ## Define utility functions for processing results

# %%
def calc_individual_response_times(df, query):
    """Calculate individual response times based on the moving average stored by locust"""
    subset = df[df["Name"] == query]
    subset = subset.drop_duplicates(subset="Total Request Count", keep="last")
    subset = subset.set_index("Total Request Count")
    for ind, row in subset.iterrows():
        if ind == 1:
            subset.loc[ind, "Response Time"] = subset.loc[
                ind, "Total Average Response Time"
            ]
        elif ind == 2 and 1 not in subset.index.unique():
            subset.loc[ind, "Response Time"] = subset.loc[
                ind, "Total Max Response Time"
            ]
            subset.loc[1] = subset.loc[ind]
            subset.loc[1, "Total Request Count"] = 1
            subset.loc[1, "Response Time"] = subset.loc[ind, "Total Min Response Time"]
        else:
            subset.loc[ind, "Response Time"] = (
                ind * subset.loc[ind, "Total Average Response Time"]
                - (ind - 1) * subset.loc[ind - 1, "Total Average Response Time"]
            )
    subset = subset[["Name", "Response Time"]]
    return subset

# %%
def split_aggregated_results(df, full_df):
    """Transform aggregated results into individual response times"""
    queries = df[df["Request Count"] > 1]["Name"].to_list()
    df = df[df["Request Count"] == 1]
    df = df.rename(columns={"Average Response Time": "Response Time"})
    df = df[["Name", "Request Count", "Response Time", "Min Response Time"]]
    for query in queries:
        split_data = calc_individual_response_times(full_df, query)
        df = pd.concat([df, split_data], axis=0)
    return df

# %%
def process_locust_results(results_location):
    """Load locust results and extract relevant information"""
    df = pd.read_csv(f"{results_location}_stats.csv")
    full_results = pd.read_csv(f"{results_location}_stats_history.csv")
    df = df[df["Type"] == "GET"]
    df = split_aggregated_results(df, full_results)
    df["zoom"] = df.apply(lambda x: int(x["Name"].split("?")[0].split("/")[3]), axis=1)
    df["tile"] = df.apply(lambda x: x["Name"].split("?")[0].split("/")[3:6], axis=1)

    df = df.rename(columns={"Name": "query"})
    df["method"] = "FastAPI"
    return df

# %% [markdown]
# ## Process locust results and merge with CMRBackend results

# %%
locust_df = process_locust_results(results_output)
df["method"] = "CMRBackend"
df["Response Time"] = df.apply(lambda x: float(x["timings"][0]), axis=1)
df = df[["query", "Response Time", "method", "tile", "zoom"]]
combined_df = pd.concat([df, locust_df], axis=0).reset_index()

# %% [markdown]
# ## Plot results

# %%
cmap = ["#E1BE6A", "#40B0A6"]
plt_opts = {"width": 1800, "height": 400, "xrotation": 90}

# %%
combined_df.hvplot.box(
    y="Response Time",
    by=["zoom", "method"],
    c="method",
    cmap=cmap,
    ylabel="Response time (s)",
    xlabel="Zoom level",
    legend=False,
).opts(**plt_opts)
# Out:
# BokehUserWarning: ColumnDataSource's columns must be of the same length. Current lengths: ('Response Time', 23), ('Response_Time', 0), ('index', 23)
# BokehUserWarning: ColumnDataSource's columns must be of the same length. Current lengths: ('Response Time', 23), ('Response_Time', 0), ('index', 23)
# :BoxWhisker   [zoom,method]   (Response Time)
